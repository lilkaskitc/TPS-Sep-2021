# %%
import numpy as np
import pandas as pd
import random
import os
import time
import pickle
from pathlib import Path

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import roc_auc_score

import lightgbm as lgb
#import xgboost as xgb
#import catboost as ctb

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter('ignore')
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %% [markdown]
# # Parameters

# %%
target = 'claim'

DEBUG = False

if DEBUG:
    N_ESTIMATORS = 1
    N_SPLITS = 2
    SEED = 2017
    CVSEED = 2017
    EARLY_STOPPING_ROUNDS = 1
    VERBOSE = 100
    #N_ITERS = 2
else:
    N_SPLITS = 10
    N_ESTIMATORS = 20000
    EARLY_STOPPING_ROUNDS = 300
    VERBOSE = 1000
    SEED = 2017
    CVSEED = 2017
    #N_ITERS = 10

# %%
def set_seed(seed=2017):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    
set_seed(SEED)

# %% [markdown]
# # Datasets

# %%
INPUT = Path("../input/tabular-playground-series-sep-2021")

train = pd.read_csv(INPUT / "train.csv")
test = pd.read_csv(INPUT / "test.csv")
submission = pd.read_csv(INPUT / "sample_solution.csv")

# %% [markdown]
# # Preprocessing

# %%
features = [col for col in train.columns if 'f' in col]

# %%
train['n_missing'] = train[features].isna().sum(axis=1)
test['n_missing'] = test[features].isna().sum(axis=1)

features += ['n_missing']

# %%
train[features] = train[features].fillna(train[features].median())
test[features] = test[features].fillna(test[features].median())

# %%
ss = StandardScaler()

# %%
test[features]
# Out:
#               f1        f2        f3        f4       f5        f6       f7  \
# 0       0.165850  0.487050   1295.00  0.023100  0.31900  0.901880   573.29
# 1       0.129650  0.373480   1763.00  0.728840  0.33247 -1.263100   875.55
# 2       0.120190  0.445210    736.26  0.046150  0.29605  0.316650  2659.50
# 3       0.054008  0.395960    996.14  0.859340  0.36678 -0.170600   386.56
# 4       0.079947 -0.006919  10574.00  0.348450  0.45008 -1.842000  3027.00
# ...          ...       ...       ...       ...      ...       ...      ...
# 493469 -0.009112  0.308190    637.64  0.778200  0.41415 -1.068500   651.22
# 493470  0.088922  0.482650   6924.10  0.025963  0.35540 -0.870200  2514.20
# 493471  0.140620  0.484750   1797.10  0.147020  0.28803 -1.407100   434.03
# 493472  0.168000  0.351760    454.79  0.164580  0.16983  0.323850  2331.20
# 493473  0.093079  0.501860   3322.40  0.137350  0.33269  0.056827  2568.70
#
#               f8            f9           f10  ...     f110    f111  \
# 0         3743.7  2.705700e+12   6221.000000  ... -22.1890  2.0655
# 1       554370.0  5.955700e+14    934.430000  ...  -1.6342  1.5736
# 2       317140.0  3.977800e+14    131.810000  ... -32.7800  2.1364
# 3       325680.0 -3.432200e+13    -26.473000  ...  -2.4162  1.5199
# 4       428150.0  9.291500e+11   5999.400000  ... -18.6300  3.7387
# ...          ...           ...           ...  ...      ...     ...
# 493469  985000.0  6.079700e+15    508.820000  ... -17.5100  2.3325
# 493470   18004.0  6.073500e+14     -0.008665  ...  -7.8690  1.7005
# 493471  333050.0  2.351000e+15  33492.000000  ...  -5.3824  1.6827
# 493472  223980.0 -2.795300e+12     93.561000  ...  -4.2416  1.3531
# 493473   39185.0  1.489300e+14   -318.920000  ... -13.9390  1.4480
#
#               f112     f113      f114    f115          f116     f117     f118  \
# 0         0.430880 -10.7410  81606.00  1.1940  1.980400e+14  2017.10  0.46357
# 1        -1.071200  11.8320  90114.00  1.1507  4.388000e+16  6638.90  0.28125
# 2        -1.931200  -3.2804  37739.00  1.1548  1.718100e+14  5844.00  0.13797
# 3        -0.011633   1.3840  26849.00  1.1490  2.138800e+17  6173.30  0.32910
# 4         0.757080  -4.9405  50336.00  1.2488  2.151300e+17  2250.10  0.33796
# ...            ...      ...       ...     ...           ...      ...      ...
# 493469    0.112260  -5.9238  19429.00  1.1559  8.163900e+16   857.09  1.56330
# 493470   97.813000   4.3793  -2432.00  1.0707  4.691800e+16  7497.10  0.67075
# 493471    1.730400   8.0633   2471.40  1.1725  7.900900e+16  2904.60  0.18005
# 493472  155.210000  13.9630    -11.44  1.1946 -1.770600e+14  6763.10  0.33223
# 493473   -1.512900 -15.4360    662.46  1.1778  2.459300e+15  8770.00  0.95503
#
#         n_missing
# 0               1
# 1               0
# 2               1
# 3               0
# 4               0
# ...           ...
# 493469          2
# 493470          0
# 493471          5
# 493472          0
# 493473          6
#
# [493474 rows x 119 columns]

# %%
train[target]
# Out:
# 0         1
# 1         0
# 2         1
# 3         1
# 4         1
#          ..
# 957914    0
# 957915    1
# 957916    0
# 957917    1
# 957918    0
# Name: claim, Length: 957919, dtype: int64

# %% [markdown]
# # LGB

# %%
lgb_params = {
    'objective': 'binary',
     'n_estimators':N_ESTIMATORS,
     'importance_type': 'gain',
     'metric':'auc',
     'boosting_type': 'gbdt',
     'n_jobs' : -1,
        
    'learning_rate': 0.0654264621132775,
    'subsample': 0.9277539941320031,
    'subsample_freq': 8,
    'colsample_bytree': 0.2917976531741996, 
    'reg_lambda': 0.0006975369134078038,
    'reg_alpha': 0.000507261979590017,
    'min_child_weight': 28.01635169501754, 
    'min_child_samples': 88, 
    'num_leaves': 218, 
    'max_depth': 3, 
    'max_bin': 242
}

# %%
lgb_oof = np.zeros(train.shape[0])
lgb_pred = np.zeros(test.shape[0])
lgb_importances = pd.DataFrame()


kf = StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=CVSEED)
seed_list=[SEED+18, SEED+19]

for fold, (trn_idx, val_idx) in enumerate(kf.split(X=train[features], y=train[target])):
    print(f"===== fold {fold} =====")


    X_train = train[features].iloc[trn_idx]
    y_train = train[target].iloc[trn_idx]
    X_valid = train[features].iloc[val_idx]
    y_valid = train[target].iloc[val_idx]
    X_test = test[features]

    X_train[features] = ss.fit_transform(X_train[features])
    X_valid[features] = ss.transform(X_valid[features])
    X_test[features] = ss.transform(X_test[features])

    start = time.time()
    for inseed in seed_list:
        lgb_params['random_state'] = inseed

        pre_model = lgb.LGBMClassifier(**lgb_params)
        pre_model.fit(
            X_train, 
            y_train,
            eval_set=[(X_valid, y_valid)],
            eval_metric='auc',
            early_stopping_rounds=EARLY_STOPPING_ROUNDS,
            verbose=VERBOSE,
        )

        lgb_params2 = lgb_params.copy()
        lgb_params2['reg_lambda'] *= 0.9
        lgb_params2['reg_alpha'] *= 0.9
        lgb_params2['learning_rate'] *= 0.1
        model = lgb.LGBMClassifier(**lgb_params2)
        model.fit(
                X_train, y_train,
                eval_set=[(X_valid, y_valid)],
                eval_metric='auc',
                early_stopping_rounds=EARLY_STOPPING_ROUNDS,
                verbose=VERBOSE,
                init_model=pre_model
        )    

        with open(f"lgb_model{fold}_seed{inseed}.pkl", 'wb') as f:
            pickle.dump(model, f)

        fi_tmp = pd.DataFrame()
        fi_tmp['feature'] = model.feature_name_
        fi_tmp['importance'] = model.feature_importances_
        fi_tmp['fold'] = fold
        fi_tmp['seed'] = inseed
        lgb_importances = lgb_importances.append(fi_tmp)

        lgb_oof[val_idx] += model.predict_proba(X_valid)[:,-1] / len(seed_list)
        lgb_pred += model.predict_proba(X_test)[:,-1] / len(seed_list)


    elapsed = time.time() - start
    auc = roc_auc_score(y_valid, lgb_oof[val_idx])
    print(f"fold {fold} - lgb auc: {auc:.6f}, elapsed time: {elapsed:.2f}sec\n")            

lgb_pred /= N_SPLITS
print(f"oof lgb_auc = {roc_auc_score(train[target], lgb_oof)}")

np.save("lgb_oof.npy", lgb_oof)
np.save("lgb_pred.npy", lgb_pred)
# Out:
# ===== fold 0 =====
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.81483
# [2000]	valid_0's auc: 0.816033
# [3000]	valid_0's auc: 0.816389
# Early stopping, best iteration is:
# [3639]	valid_0's auc: 0.81654
# Training until validation scores don't improve for 300 rounds
# [4000]	valid_0's auc: 0.816549
# Early stopping, best iteration is:
# [4532]	valid_0's auc: 0.816563
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.815371
# [2000]	valid_0's auc: 0.816398
# [3000]	valid_0's auc: 0.816727
# Early stopping, best iteration is:
# [2883]	valid_0's auc: 0.816747
# Training until validation scores don't improve for 300 rounds
# [3000]	valid_0's auc: 0.816752
# [4000]	valid_0's auc: 0.816786
# Early stopping, best iteration is:
# [4514]	valid_0's auc: 0.816794
# fold 0 - lgb auc: 0.816959, elapsed time: 1017.35sec
#
# ===== fold 1 =====
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.813852
# [2000]	valid_0's auc: 0.815155
# [3000]	valid_0's auc: 0.815605
# Early stopping, best iteration is:
# [3202]	valid_0's auc: 0.815721
# Training until validation scores don't improve for 300 rounds
# [4000]	valid_0's auc: 0.815737
# Early stopping, best iteration is:
# [4082]	valid_0's auc: 0.815741
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.81423
# [2000]	valid_0's auc: 0.81511
# [3000]	valid_0's auc: 0.815355
# Early stopping, best iteration is:
# [3256]	valid_0's auc: 0.815492
# Training until validation scores don't improve for 300 rounds
# [4000]	valid_0's auc: 0.81552
# [5000]	valid_0's auc: 0.815539
# Early stopping, best iteration is:
# [5368]	valid_0's auc: 0.815554
# fold 1 - lgb auc: 0.815947, elapsed time: 1086.98sec
#
# ===== fold 2 =====
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.81534
# [2000]	valid_0's auc: 0.81619
# [3000]	valid_0's auc: 0.816603
# Early stopping, best iteration is:
# [3249]	valid_0's auc: 0.816663
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [3451]	valid_0's auc: 0.816668
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.815402
# [2000]	valid_0's auc: 0.816598
# [3000]	valid_0's auc: 0.816955
# Early stopping, best iteration is:
# [3297]	valid_0's auc: 0.817031
# Training until validation scores don't improve for 300 rounds
# [4000]	valid_0's auc: 0.817055
# Early stopping, best iteration is:
# [4594]	valid_0's auc: 0.817072
# fold 2 - lgb auc: 0.817152, elapsed time: 881.52sec
#
# ===== fold 3 =====
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.814408
# [2000]	valid_0's auc: 0.815331
# Early stopping, best iteration is:
# [2437]	valid_0's auc: 0.815473
# Training until validation scores don't improve for 300 rounds
# [3000]	valid_0's auc: 0.815507
# [4000]	valid_0's auc: 0.81556
# Early stopping, best iteration is:
# [4190]	valid_0's auc: 0.815561
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.81428
# [2000]	valid_0's auc: 0.815199
# [3000]	valid_0's auc: 0.815581
# Early stopping, best iteration is:
# [3412]	valid_0's auc: 0.815714
# Training until validation scores don't improve for 300 rounds
# [4000]	valid_0's auc: 0.815722
# Early stopping, best iteration is:
# [4470]	valid_0's auc: 0.815729
# fold 3 - lgb auc: 0.815939, elapsed time: 915.67sec
#
# ===== fold 4 =====
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.815948
# [2000]	valid_0's auc: 0.816936
# Early stopping, best iteration is:
# [2485]	valid_0's auc: 0.817151
# Training until validation scores don't improve for 300 rounds
# [3000]	valid_0's auc: 0.817174
# [4000]	valid_0's auc: 0.8172
# [5000]	valid_0's auc: 0.817233
# [6000]	valid_0's auc: 0.817265
# Early stopping, best iteration is:
# [6226]	valid_0's auc: 0.817271
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.815921
# [2000]	valid_0's auc: 0.816968
# [3000]	valid_0's auc: 0.817163
# Early stopping, best iteration is:
# [2853]	valid_0's auc: 0.817231
# Training until validation scores don't improve for 300 rounds
# [3000]	valid_0's auc: 0.817237
# [4000]	valid_0's auc: 0.817269
# [5000]	valid_0's auc: 0.817292
# Early stopping, best iteration is:
# [4987]	valid_0's auc: 0.817295
# fold 4 - lgb auc: 0.817540, elapsed time: 1151.14sec
#
# ===== fold 5 =====
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.812715
# [2000]	valid_0's auc: 0.814076
# [3000]	valid_0's auc: 0.814322
# [4000]	valid_0's auc: 0.814473
# Early stopping, best iteration is:
# [3709]	valid_0's auc: 0.814493
# Training until validation scores don't improve for 300 rounds
# [4000]	valid_0's auc: 0.814504
# [5000]	valid_0's auc: 0.814534
# [6000]	valid_0's auc: 0.814551
# Early stopping, best iteration is:
# [6350]	valid_0's auc: 0.814566
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.812871
# [2000]	valid_0's auc: 0.814032
# [3000]	valid_0's auc: 0.814512
# Early stopping, best iteration is:
# [3094]	valid_0's auc: 0.814578
# Training until validation scores don't improve for 300 rounds
# [4000]	valid_0's auc: 0.814596
# Early stopping, best iteration is:
# [4409]	valid_0's auc: 0.81461
# fold 5 - lgb auc: 0.814883, elapsed time: 1222.36sec
#
# ===== fold 6 =====
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.817702
# [2000]	valid_0's auc: 0.818751
# Early stopping, best iteration is:
# [2387]	valid_0's auc: 0.818938
# Training until validation scores don't improve for 300 rounds
# [3000]	valid_0's auc: 0.818948
# Early stopping, best iteration is:
# [3139]	valid_0's auc: 0.818957
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.817656
# [2000]	valid_0's auc: 0.818712
# Early stopping, best iteration is:
# [2327]	valid_0's auc: 0.818837
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [2481]	valid_0's auc: 0.818841
# fold 6 - lgb auc: 0.819154, elapsed time: 714.73sec
#
# ===== fold 7 =====
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.81335
# [2000]	valid_0's auc: 0.814495
# [3000]	valid_0's auc: 0.81469
# Early stopping, best iteration is:
# [2805]	valid_0's auc: 0.81476
# Training until validation scores don't improve for 300 rounds
# [3000]	valid_0's auc: 0.814774
# [4000]	valid_0's auc: 0.814796
# [5000]	valid_0's auc: 0.814826
# [6000]	valid_0's auc: 0.814838
# Early stopping, best iteration is:
# [6252]	valid_0's auc: 0.814855
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.813357
# [2000]	valid_0's auc: 0.814384
# Early stopping, best iteration is:
# [2607]	valid_0's auc: 0.814686
# Training until validation scores don't improve for 300 rounds
# [3000]	valid_0's auc: 0.814696
# [4000]	valid_0's auc: 0.814722
# [5000]	valid_0's auc: 0.814735
# Early stopping, best iteration is:
# [4793]	valid_0's auc: 0.814738
# fold 7 - lgb auc: 0.815051, elapsed time: 1153.41sec
#
# ===== fold 8 =====
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.814748
# [2000]	valid_0's auc: 0.81587
# [3000]	valid_0's auc: 0.816254
# Early stopping, best iteration is:
# [3266]	valid_0's auc: 0.816293
# Training until validation scores don't improve for 300 rounds
# [4000]	valid_0's auc: 0.816305
# Early stopping, best iteration is:
# [3875]	valid_0's auc: 0.816307
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.815122
# [2000]	valid_0's auc: 0.815991
# [3000]	valid_0's auc: 0.816202
# Early stopping, best iteration is:
# [3507]	valid_0's auc: 0.816269
# Training until validation scores don't improve for 300 rounds
# [4000]	valid_0's auc: 0.816284
# [5000]	valid_0's auc: 0.816306
# Early stopping, best iteration is:
# [4734]	valid_0's auc: 0.81631
# fold 8 - lgb auc: 0.816623, elapsed time: 952.06sec
#
# ===== fold 9 =====
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.813846
# [2000]	valid_0's auc: 0.815041
# [3000]	valid_0's auc: 0.815329
# Early stopping, best iteration is:
# [3271]	valid_0's auc: 0.815419
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [3310]	valid_0's auc: 0.81542
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.814114
# [2000]	valid_0's auc: 0.81524
# [3000]	valid_0's auc: 0.81557
# [4000]	valid_0's auc: 0.815797
# Early stopping, best iteration is:
# [3924]	valid_0's auc: 0.815855
# Training until validation scores don't improve for 300 rounds
# [4000]	valid_0's auc: 0.815857
# Early stopping, best iteration is:
# [4044]	valid_0's auc: 0.815861
# fold 9 - lgb auc: 0.815952, elapsed time: 852.63sec
#
# oof lgb_auc = 0.8165119930715696

# %% [markdown]
# # OOF predictions

# %%
plt.plot(train[target], train[target])
plt.scatter(train[target], lgb_oof)

# %% [markdown]
# # Features importances

# %%
order = list(lgb_importances.groupby('feature').mean().sort_values('importance', ascending=False).index)

fig = plt.figure(figsize=(16, 16), tight_layout=True)
sns.barplot(x="importance", y="feature", data=lgb_importances.groupby('feature').mean().reset_index(), order=order)
plt.title("LightGBM feature importances")
# Out:
# Text(0.5, 1.0, 'LightGBM feature importances')

# %% [markdown]
# # Submission

# %%
submission[target] = lgb_pred
submission.to_csv("submission.csv", index=False)

submission
# Out:
#              id     claim
# 0        957919  0.563142
# 1        957920  0.129192
# 2        957921  0.637790
# 3        957922  0.123149
# 4        957923  0.150983
# ...         ...       ...
# 493469  1451388  0.834759
# 493470  1451389  0.114996
# 493471  1451390  0.770832
# 493472  1451391  0.131993
# 493473  1451392  0.742346
#
# [493474 rows x 2 columns]

# %% [markdown]
# # Log
#
# seeds
# 2017-2019 ver2
# 2020-2024 ver3
# 2025-2029 ver4
# 2030-2034 ver5
# 2035-2036 ver6
