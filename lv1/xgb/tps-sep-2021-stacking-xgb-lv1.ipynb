# %%
import numpy as np
import pandas as pd
import random
import os
import time
import pickle
from pathlib import Path

from sklearn.preprocessing import StandardScaler, QuantileTransformer
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import roc_auc_score

#import lightgbm as lgb
import xgboost as xgb
#import catboost as ctb

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# # Parameters

# %%
target = 'claim'

DEBUG = False

if DEBUG:
    N_ESTIMATORS = 1
    N_SPLITS = 2
    SEED = 2017
    CVSEED = 2017
    EARLY_STOPPING_ROUNDS = 1
    VERBOSE = 100
    #N_ITERS = 2
else:
    N_SPLITS = 10
    N_ESTIMATORS = 20000
    EARLY_STOPPING_ROUNDS = 300
    VERBOSE = 1000
    SEED = 2017
    CVSEED = 2017
    #N_ITERS = 10

# %%
def set_seed(seed=2017):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    
set_seed(SEED)

# %% [markdown]
# # Datasets

# %%
INPUT = Path("../input/tabular-playground-series-sep-2021")

train = pd.DataFrame(pd.read_csv(INPUT / "train.csv")[target])
#test = pd.read_csv(INPUT / "test.csv")
test = pd.DataFrame()
submission = pd.read_csv(INPUT / "sample_solution.csv")

# %%
train['lgb_pred'] = np.load("../input/tps-sep-lv0-base-trees/agg_lgb_oof.npy")
test['lgb_pred'] = np.load("../input/tps-sep-lv0-base-trees/agg_lgb_pred.npy")

train['lgb2_pred'] = np.load("../input/tps-sep-lv0-base-trees/agg_lgb2_oof.npy")
test['lgb2_pred'] = np.load("../input/tps-sep-lv0-base-trees/agg_lgb2_pred.npy")

train['xgb_pred'] = np.load("../input/tps-sep-lv0-base-trees/agg_xgb_oof.npy")
test['xgb_pred'] = np.load("../input/tps-sep-lv0-base-trees/agg_xgb_pred.npy")

train['lgb_bizen_pred'] = np.load("../input/tps-sep-lv0-base-trees/lgb_bizen_oof.npy")
test['lgb_bizen_pred'] = np.load("../input/tps-sep-lv0-base-trees/lgb_bizen_pred.npy")

train['lgb_dmitry_pred'] = np.load("../input/tps-sep-lv0-base-trees/lgb_dmitry_oof.npy")
test['lgb_dmitry_pred'] = np.load("../input/tps-sep-lv0-base-trees/lgb_dmitry_pred.npy")

train['xgb_dmitry_pred'] = np.load("../input/tps-sep-lv0-base-trees/xgb_dmitry_oof.npy")
test['xgb_dmitry_pred'] = np.load("../input/tps-sep-lv0-base-trees/xgb_dmitry_pred.npy")

train['lgb_manav_pred'] = np.load("../input/tps-sep-lv0-base-trees/lgb_manav_oof.npy")
test['lgb_manav_pred'] = np.load("../input/tps-sep-lv0-base-trees/lgb_manav_pred.npy")

train['xgb_manav_pred'] = np.load("../input/tps-sep-lv0-base-trees/xgb_manav_oof.npy")
test['xgb_manav_pred'] = np.load("../input/tps-sep-lv0-base-trees/xgb_manav_pred.npy")

# %%
train['ridge_pred'] = np.load("../input/tps-sep-lv0-base-trees/ridge_oof.npy")
test['ridge_pred'] = np.load("../input/tps-sep-lv0-base-trees/ridge_pred.npy")

# %% [markdown]
# # Preprocessing

# %%
features = [col for col in train.columns if 'pred' in col]

# %%
ss = StandardScaler()

# %%
test[features]
# Out:
#         lgb_pred  lgb2_pred  xgb_pred  lgb_bizen_pred  lgb_dmitry_pred  \
# 0       0.558734   0.578699  0.576973        0.561836         0.566536
# 1       0.130124   0.120648  0.124073        0.119917         0.126946
# 2       0.634854   0.628457  0.630655        0.629326         0.627686
# 3       0.121661   0.125785  0.126651        0.128635         0.122506
# 4       0.151700   0.150161  0.149483        0.153291         0.146343
# ...          ...        ...       ...             ...              ...
# 493469  0.833647   0.829336  0.829659        0.827457         0.825696
# 493470  0.114116   0.116351  0.117947        0.111374         0.112238
# 493471  0.771955   0.760704  0.758474        0.758873         0.764026
# 493472  0.129603   0.132275  0.129645        0.133944         0.135123
# 493473  0.742763   0.748962  0.749504        0.757657         0.744380
#
#         xgb_dmitry_pred  lgb_manav_pred  xgb_manav_pred  ridge_pred
# 0              0.575204        0.564575        0.564908    0.553440
# 1              0.126340        0.121656        0.120459    0.182040
# 2              0.635330        0.626681        0.633499    0.631720
# 3              0.123506        0.128684        0.131022    0.184237
# 4              0.143437        0.152862        0.153132    0.203202
# ...                 ...             ...             ...         ...
# 493469         0.827184        0.831222        0.816129    0.790480
# 493470         0.115928        0.111981        0.109487    0.174385
# 493471         0.754300        0.756039        0.774203    0.751130
# 493472         0.132036        0.135098        0.136081    0.184900
# 493473         0.747717        0.741040        0.760795    0.734600
#
# [493474 rows x 9 columns]

# %%
train[target]
# Out:
# 0         1
# 1         0
# 2         1
# 3         1
# 4         1
#          ..
# 957914    0
# 957915    1
# 957916    0
# 957917    1
# 957918    0
# Name: claim, Length: 957919, dtype: int64

# %% [markdown]
# # XGB

# %%
xgb_params = {
            'objective': 'binary:logistic',                   
          'n_estimators':N_ESTIMATORS,                   
          'importance_type': 'total_gain',               
          'booster': 'gbtree',                   
          'n_jobs' : -1,                
          'tree_method': 'hist',    
    
     'learning_rate': 0.01805802806162393,
     'subsample': 0.4014133642323718,
     'colsample_bytree': 0.9129261289649728,
     'reg_lambda': 0.4746414387266343,
     'reg_alpha': 0.21152645002896442,
     'min_child_weight': 28.051170865462655,
     'max_depth': 2,
     'max_bin': 552,
     'gamma': 8.244492575974531
}

# %%
xgb_oof = np.zeros(train.shape[0])
xgb_pred = np.zeros(test.shape[0])
xgb_importances = pd.DataFrame()


kf = StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=CVSEED)
seed_list=range(SEED, SEED+20)

for fold, (trn_idx, val_idx) in enumerate(kf.split(X=train[features], y=train[target])):
    print(f"===== fold {fold} =====")


    X_train = train[features].iloc[trn_idx]
    y_train = train[target].iloc[trn_idx]
    X_valid = train[features].iloc[val_idx]
    y_valid = train[target].iloc[val_idx]
    X_test = test[features]
      
        
    X_train[features] = ss.fit_transform(X_train[features])
    X_valid[features] = ss.transform(X_valid[features])
    X_test[features] = ss.transform(X_test[features])

    start = time.time()
    for inseed in seed_list:
        xgb_params['random_state'] = inseed

        pre_model = xgb.XGBClassifier(**xgb_params)
        pre_model.fit(
            X_train, 
            y_train,
            eval_set=[(X_valid, y_valid)],
            eval_metric='auc',
            early_stopping_rounds=EARLY_STOPPING_ROUNDS,
            verbose=VERBOSE,
        )

        xgb_params2 = xgb_params.copy()
        xgb_params2['reg_lambda'] *= 0.9
        xgb_params2['reg_alpha'] *= 0.9
        xgb_params2['learning_rate'] *= 0.1
        model = xgb.XGBClassifier(**xgb_params2)
        model.fit(
                X_train, y_train,
                eval_set=[(X_valid, y_valid)],
                eval_metric='auc',
                early_stopping_rounds=EARLY_STOPPING_ROUNDS,
                verbose=VERBOSE,
                xgb_model=pre_model
        )    

        with open(f"xgb_model{fold}_seed{inseed}.pkl", 'wb') as f:
            pickle.dump(model, f)

        fi_tmp = pd.DataFrame()
        fi_tmp['feature'] = X_train.columns
        fi_tmp['importance'] = model.feature_importances_
        fi_tmp['fold'] = fold
        fi_tmp['seed'] = inseed
        xgb_importances = xgb_importances.append(fi_tmp)

        xgb_oof[val_idx] += model.predict_proba(X_valid)[:,-1] / len(seed_list)
        xgb_pred += model.predict_proba(X_test)[:,-1] / len(seed_list)


    elapsed = time.time() - start
    auc = roc_auc_score(y_valid, xgb_oof[val_idx])
    print(f"fold {fold} - xgb auc: {auc:.6f}, elapsed time: {elapsed:.2f}sec\n")            

xgb_pred /= N_SPLITS
print(f"oof xgb_auc = {roc_auc_score(train[target], xgb_oof)}")

np.save("xgb_oof.npy", xgb_oof)
np.save("xgb_pred.npy", xgb_pred)
# Out:
# ===== fold 0 =====
# [0]	validation_0-auc:0.80461
# [827]	validation_0-auc:0.81730
# [0]	validation_0-auc:0.81730
# [299]	validation_0-auc:0.81730
# [0]	validation_0-auc:0.80461
# [1000]	validation_0-auc:0.81736
# [1605]	validation_0-auc:0.81737
# [0]	validation_0-auc:0.81737
# [517]	validation_0-auc:0.81737
# [0]	validation_0-auc:0.80441
# [1000]	validation_0-auc:0.81734
# [1082]	validation_0-auc:0.81733
# [0]	validation_0-auc:0.81734
# [560]	validation_0-auc:0.81733
# [0]	validation_0-auc:0.80490
# [1000]	validation_0-auc:0.81734
# [1040]	validation_0-auc:0.81735
# [0]	validation_0-auc:0.81735
# [300]	validation_0-auc:0.81734
# [0]	validation_0-auc:0.80319
# [879]	validation_0-auc:0.81736
# [0]	validation_0-auc:0.81736
# [341]	validation_0-auc:0.81736
# [0]	validation_0-auc:0.80390
# [1000]	validation_0-auc:0.81733
# [1690]	validation_0-auc:0.81736
# [0]	validation_0-auc:0.81736
# [325]	validation_0-auc:0.81735
# [0]	validation_0-auc:0.80417
# [851]	validation_0-auc:0.81731
# [0]	validation_0-auc:0.81731
# [300]	validation_0-auc:0.81731
# [0]	validation_0-auc:0.80492
# [624]	validation_0-auc:0.81734
# [0]	validation_0-auc:0.81734
# [1000]	validation_0-auc:0.81735
# [1114]	validation_0-auc:0.81735
# [0]	validation_0-auc:0.80314
# [1000]	validation_0-auc:0.81738
# [1229]	validation_0-auc:0.81736
# [0]	validation_0-auc:0.81736
# [394]	validation_0-auc:0.81736
# [0]	validation_0-auc:0.80459
# [840]	validation_0-auc:0.81736
# [0]	validation_0-auc:0.81736
# [300]	validation_0-auc:0.81736
# [0]	validation_0-auc:0.80420
# [1000]	validation_0-auc:0.81737
# [1122]	validation_0-auc:0.81736
# [0]	validation_0-auc:0.81736
# [402]	validation_0-auc:0.81736
# [0]	validation_0-auc:0.80312
# [515]	validation_0-auc:0.81735
# [0]	validation_0-auc:0.81735
# [613]	validation_0-auc:0.81735
# [0]	validation_0-auc:0.80386
# [977]	validation_0-auc:0.81736
# [0]	validation_0-auc:0.81736
# [658]	validation_0-auc:0.81737
# [0]	validation_0-auc:0.80376
# [1000]	validation_0-auc:0.81734
# [1023]	validation_0-auc:0.81734
# [0]	validation_0-auc:0.81734
# [299]	validation_0-auc:0.81734
# [0]	validation_0-auc:0.80470
# [554]	validation_0-auc:0.81736
# [0]	validation_0-auc:0.81736
# [334]	validation_0-auc:0.81736
# [0]	validation_0-auc:0.80327
# [1000]	validation_0-auc:0.81736
# [1286]	validation_0-auc:0.81734
# [0]	validation_0-auc:0.81734
# [300]	validation_0-auc:0.81734
# [0]	validation_0-auc:0.80436
# [585]	validation_0-auc:0.81732
# [0]	validation_0-auc:0.81732
# [547]	validation_0-auc:0.81733
# [0]	validation_0-auc:0.80459
# [562]	validation_0-auc:0.81730
# [0]	validation_0-auc:0.81730
# [729]	validation_0-auc:0.81730
# [0]	validation_0-auc:0.80321
# [1000]	validation_0-auc:0.81739
# [1122]	validation_0-auc:0.81739
# [0]	validation_0-auc:0.81739
# [889]	validation_0-auc:0.81739
# [0]	validation_0-auc:0.80332
# [884]	validation_0-auc:0.81733
# [0]	validation_0-auc:0.81734
# [331]	validation_0-auc:0.81733
# fold 0 - xgb auc: 0.817352, elapsed time: 1938.54sec
#
# ===== fold 1 =====
# [0]	validation_0-auc:0.80249
# [1000]	validation_0-auc:0.81634
# [1290]	validation_0-auc:0.81632
# [0]	validation_0-auc:0.81632
# [348]	validation_0-auc:0.81632
# [0]	validation_0-auc:0.80180
# [1000]	validation_0-auc:0.81633
# [1989]	validation_0-auc:0.81635
# [0]	validation_0-auc:0.81635
# [835]	validation_0-auc:0.81635
# [0]	validation_0-auc:0.80226
# [1000]	validation_0-auc:0.81635
# [1091]	validation_0-auc:0.81634
# [0]	validation_0-auc:0.81634
# [816]	validation_0-auc:0.81635
# [0]	validation_0-auc:0.80091
# [484]	validation_0-auc:0.81634
# [0]	validation_0-auc:0.81634
# [360]	validation_0-auc:0.81634
# [0]	validation_0-auc:0.80223
# [1000]	validation_0-auc:0.81641
# [1526]	validation_0-auc:0.81640
# [0]	validation_0-auc:0.81640
# [371]	validation_0-auc:0.81640
# [0]	validation_0-auc:0.80147
# [1000]	validation_0-auc:0.81632
# [1458]	validation_0-auc:0.81634
# [0]	validation_0-auc:0.81634
# [379]	validation_0-auc:0.81634
# [0]	validation_0-auc:0.80226
# [644]	validation_0-auc:0.81630
# [0]	validation_0-auc:0.81630
# [1000]	validation_0-auc:0.81631
# [1208]	validation_0-auc:0.81631
# [0]	validation_0-auc:0.80277
# [1000]	validation_0-auc:0.81639
# [1021]	validation_0-auc:0.81639
# [0]	validation_0-auc:0.81639
# [312]	validation_0-auc:0.81639
# [0]	validation_0-auc:0.80196
# [1000]	validation_0-auc:0.81636
# [2000]	validation_0-auc:0.81639
# [2077]	validation_0-auc:0.81639
# [0]	validation_0-auc:0.81639
# [395]	validation_0-auc:0.81639
# [0]	validation_0-auc:0.80156
# [1000]	validation_0-auc:0.81633
# [1164]	validation_0-auc:0.81634
# [0]	validation_0-auc:0.81634
# [564]	validation_0-auc:0.81634
# [0]	validation_0-auc:0.80177
# [1000]	validation_0-auc:0.81637
# [1007]	validation_0-auc:0.81637
# [0]	validation_0-auc:0.81637
# [816]	validation_0-auc:0.81638
# [0]	validation_0-auc:0.80280
# [670]	validation_0-auc:0.81633
# [0]	validation_0-auc:0.81633
# [490]	validation_0-auc:0.81634
# [0]	validation_0-auc:0.80077
# [1000]	validation_0-auc:0.81635
# [1088]	validation_0-auc:0.81636
# [0]	validation_0-auc:0.81636
# [343]	validation_0-auc:0.81636
# [0]	validation_0-auc:0.80083
# [1000]	validation_0-auc:0.81640
# [1271]	validation_0-auc:0.81639
# [0]	validation_0-auc:0.81639
# [517]	validation_0-auc:0.81640
# [0]	validation_0-auc:0.80293
# [1000]	validation_0-auc:0.81637
# [1357]	validation_0-auc:0.81636
# [0]	validation_0-auc:0.81636
# [840]	validation_0-auc:0.81637
# [0]	validation_0-auc:0.80252
# [498]	validation_0-auc:0.81631
# [0]	validation_0-auc:0.81631
# [300]	validation_0-auc:0.81631
# [0]	validation_0-auc:0.80127
# [574]	validation_0-auc:0.81634
# [0]	validation_0-auc:0.81634
# [981]	validation_0-auc:0.81635
# [0]	validation_0-auc:0.80196
# [1000]	validation_0-auc:0.81639
# [1234]	validation_0-auc:0.81639
# [0]	validation_0-auc:0.81639
# [300]	validation_0-auc:0.81638
# [0]	validation_0-auc:0.80130
# [1000]	validation_0-auc:0.81640
# [1267]	validation_0-auc:0.81639
# [0]	validation_0-auc:0.81639
# [522]	validation_0-auc:0.81639
# [0]	validation_0-auc:0.80136
# [1000]	validation_0-auc:0.81637
# [1863]	validation_0-auc:0.81638
# [0]	validation_0-auc:0.81638
# [301]	validation_0-auc:0.81638
# fold 1 - xgb auc: 0.816366, elapsed time: 2273.39sec
#
# ===== fold 2 =====
# [0]	validation_0-auc:0.80437
# [876]	validation_0-auc:0.81779
# [0]	validation_0-auc:0.81779
# [346]	validation_0-auc:0.81778
# [0]	validation_0-auc:0.79951
# [722]	validation_0-auc:0.81779
# [0]	validation_0-auc:0.81779
# [547]	validation_0-auc:0.81779
# [0]	validation_0-auc:0.80226
# [474]	validation_0-auc:0.81780
# [0]	validation_0-auc:0.81780
# [395]	validation_0-auc:0.81780
# [0]	validation_0-auc:0.80259
# [438]	validation_0-auc:0.81778
# [0]	validation_0-auc:0.81778
# [912]	validation_0-auc:0.81779
# [0]	validation_0-auc:0.80219
# [1000]	validation_0-auc:0.81780
# [1002]	validation_0-auc:0.81780
# [0]	validation_0-auc:0.81780
# [494]	validation_0-auc:0.81781
# [0]	validation_0-auc:0.80205
# [1000]	validation_0-auc:0.81784
# [1322]	validation_0-auc:0.81784
# [0]	validation_0-auc:0.81784
# [811]	validation_0-auc:0.81784
# [0]	validation_0-auc:0.80344
# [446]	validation_0-auc:0.81779
# [0]	validation_0-auc:0.81779
# [550]	validation_0-auc:0.81780
# [0]	validation_0-auc:0.80103
# [458]	validation_0-auc:0.81778
# [0]	validation_0-auc:0.81778
# [348]	validation_0-auc:0.81778
# [0]	validation_0-auc:0.80196
# [445]	validation_0-auc:0.81779
# [0]	validation_0-auc:0.81779
# [299]	validation_0-auc:0.81779
# [0]	validation_0-auc:0.80331
# [969]	validation_0-auc:0.81781
# [0]	validation_0-auc:0.81781
# [299]	validation_0-auc:0.81781
# [0]	validation_0-auc:0.80204
# [676]	validation_0-auc:0.81779
# [0]	validation_0-auc:0.81779
# [797]	validation_0-auc:0.81780
# [0]	validation_0-auc:0.80272
# [1000]	validation_0-auc:0.81782
# [1399]	validation_0-auc:0.81783
# [0]	validation_0-auc:0.81783
# [318]	validation_0-auc:0.81783
# [0]	validation_0-auc:0.80257
# [1000]	validation_0-auc:0.81780
# [1276]	validation_0-auc:0.81779
# [0]	validation_0-auc:0.81779
# [736]	validation_0-auc:0.81779
# [0]	validation_0-auc:0.80346
# [1000]	validation_0-auc:0.81783
# [1322]	validation_0-auc:0.81782
# [0]	validation_0-auc:0.81782
# [517]	validation_0-auc:0.81782
# [0]	validation_0-auc:0.80284
# [429]	validation_0-auc:0.81779
# [0]	validation_0-auc:0.81779
# [351]	validation_0-auc:0.81779
# [0]	validation_0-auc:0.80226
# [1000]	validation_0-auc:0.81781
# [1451]	validation_0-auc:0.81781
# [0]	validation_0-auc:0.81781
# [491]	validation_0-auc:0.81781
# [0]	validation_0-auc:0.80280
# [504]	validation_0-auc:0.81783
# [0]	validation_0-auc:0.81783
# [338]	validation_0-auc:0.81783
# [0]	validation_0-auc:0.80191
# [1000]	validation_0-auc:0.81784
# [1207]	validation_0-auc:0.81784
# [0]	validation_0-auc:0.81783
# [323]	validation_0-auc:0.81783
# [0]	validation_0-auc:0.80387
# [499]	validation_0-auc:0.81780
# [0]	validation_0-auc:0.81780
# [410]	validation_0-auc:0.81780
# [0]	validation_0-auc:0.80198
# [858]	validation_0-auc:0.81782
# [0]	validation_0-auc:0.81782
# [302]	validation_0-auc:0.81782
# fold 2 - xgb auc: 0.817815, elapsed time: 1743.19sec
#
# ===== fold 3 =====
# [0]	validation_0-auc:0.80338
# [720]	validation_0-auc:0.81656
# [0]	validation_0-auc:0.81656
# [881]	validation_0-auc:0.81657
# [0]	validation_0-auc:0.80233
# [574]	validation_0-auc:0.81651
# [0]	validation_0-auc:0.81651
# [406]	validation_0-auc:0.81650
# [0]	validation_0-auc:0.80167
# [461]	validation_0-auc:0.81653
# [0]	validation_0-auc:0.81653
# [472]	validation_0-auc:0.81653
# [0]	validation_0-auc:0.80335
# [817]	validation_0-auc:0.81652
# [0]	validation_0-auc:0.81652
# [309]	validation_0-auc:0.81651
# [0]	validation_0-auc:0.80134
# [453]	validation_0-auc:0.81654
# [0]	validation_0-auc:0.81654
# [873]	validation_0-auc:0.81654
# [0]	validation_0-auc:0.80343
# [651]	validation_0-auc:0.81653
# [0]	validation_0-auc:0.81653
# [346]	validation_0-auc:0.81652
# [0]	validation_0-auc:0.80234
# [502]	validation_0-auc:0.81658
# [0]	validation_0-auc:0.81658
# [968]	validation_0-auc:0.81659
# [0]	validation_0-auc:0.80227
# [496]	validation_0-auc:0.81655
# [0]	validation_0-auc:0.81655
# [698]	validation_0-auc:0.81655
# [0]	validation_0-auc:0.80216
# [523]	validation_0-auc:0.81652
# [0]	validation_0-auc:0.81652
# [647]	validation_0-auc:0.81652
# [0]	validation_0-auc:0.80266
# [787]	validation_0-auc:0.81653
# [0]	validation_0-auc:0.81653
# [300]	validation_0-auc:0.81652
# [0]	validation_0-auc:0.80236
# [519]	validation_0-auc:0.81654
# [0]	validation_0-auc:0.81654
# [627]	validation_0-auc:0.81654
# [0]	validation_0-auc:0.80269
# [531]	validation_0-auc:0.81657
# [0]	validation_0-auc:0.81657
# [342]	validation_0-auc:0.81657
# [0]	validation_0-auc:0.80297
# [463]	validation_0-auc:0.81657
# [0]	validation_0-auc:0.81657
# [393]	validation_0-auc:0.81657
# [0]	validation_0-auc:0.80229
# [659]	validation_0-auc:0.81655
# [0]	validation_0-auc:0.81655
# [561]	validation_0-auc:0.81655
# [0]	validation_0-auc:0.80343
# [851]	validation_0-auc:0.81652
# [0]	validation_0-auc:0.81652
# [517]	validation_0-auc:0.81652
# [0]	validation_0-auc:0.80335
# [535]	validation_0-auc:0.81657
# [0]	validation_0-auc:0.81657
# [566]	validation_0-auc:0.81658
# [0]	validation_0-auc:0.80380
# [522]	validation_0-auc:0.81651
# [0]	validation_0-auc:0.81651
# [304]	validation_0-auc:0.81651
# [0]	validation_0-auc:0.80266
# [607]	validation_0-auc:0.81654
# [0]	validation_0-auc:0.81653
# [624]	validation_0-auc:0.81654
# [0]	validation_0-auc:0.80294
# [805]	validation_0-auc:0.81652
# [0]	validation_0-auc:0.81652
# [516]	validation_0-auc:0.81652
# [0]	validation_0-auc:0.80166
# [772]	validation_0-auc:0.81651
# [0]	validation_0-auc:0.81651
# [680]	validation_0-auc:0.81652
# fold 3 - xgb auc: 0.816541, elapsed time: 1542.24sec
#
# ===== fold 4 =====
# [0]	validation_0-auc:0.80459
# [1000]	validation_0-auc:0.81816
# [1300]	validation_0-auc:0.81816
# [0]	validation_0-auc:0.81816
# [462]	validation_0-auc:0.81816
# [0]	validation_0-auc:0.80433
# [551]	validation_0-auc:0.81817
# [0]	validation_0-auc:0.81817
# [1000]	validation_0-auc:0.81818
# [1316]	validation_0-auc:0.81818
# [0]	validation_0-auc:0.80416
# [1000]	validation_0-auc:0.81822
# [1302]	validation_0-auc:0.81822
# [0]	validation_0-auc:0.81822
# [370]	validation_0-auc:0.81822
# [0]	validation_0-auc:0.80365
# [882]	validation_0-auc:0.81816
# [0]	validation_0-auc:0.81816
# [938]	validation_0-auc:0.81816
# [0]	validation_0-auc:0.80305
# [659]	validation_0-auc:0.81817
# [0]	validation_0-auc:0.81817
# [444]	validation_0-auc:0.81817
# [0]	validation_0-auc:0.80358
# [1000]	validation_0-auc:0.81818
# [2000]	validation_0-auc:0.81822
# [2111]	validation_0-auc:0.81822
# [0]	validation_0-auc:0.81822
# [349]	validation_0-auc:0.81821
# [0]	validation_0-auc:0.80437
# [1000]	validation_0-auc:0.81817
# [1591]	validation_0-auc:0.81817
# [0]	validation_0-auc:0.81817
# [774]	validation_0-auc:0.81818
# [0]	validation_0-auc:0.80063
# [1000]	validation_0-auc:0.81820
# [1439]	validation_0-auc:0.81821
# [0]	validation_0-auc:0.81821
# [553]	validation_0-auc:0.81821
# [0]	validation_0-auc:0.80415
# [1000]	validation_0-auc:0.81817
# [1627]	validation_0-auc:0.81818
# [0]	validation_0-auc:0.81818
# [456]	validation_0-auc:0.81819
# [0]	validation_0-auc:0.80411
# [1000]	validation_0-auc:0.81818
# [1022]	validation_0-auc:0.81819
# [0]	validation_0-auc:0.81819
# [676]	validation_0-auc:0.81819
# [0]	validation_0-auc:0.80345
# [1000]	validation_0-auc:0.81818
# [2000]	validation_0-auc:0.81820
# [2272]	validation_0-auc:0.81820
# [0]	validation_0-auc:0.81820
# [300]	validation_0-auc:0.81819
# [0]	validation_0-auc:0.80416
# [1000]	validation_0-auc:0.81822
# [1669]	validation_0-auc:0.81822
# [0]	validation_0-auc:0.81822
# [312]	validation_0-auc:0.81822
# [0]	validation_0-auc:0.80340
# [1000]	validation_0-auc:0.81817
# [1301]	validation_0-auc:0.81816
# [0]	validation_0-auc:0.81816
# [299]	validation_0-auc:0.81815
# [0]	validation_0-auc:0.80462
# [1000]	validation_0-auc:0.81820
# [1081]	validation_0-auc:0.81820
# [0]	validation_0-auc:0.81820
# [516]	validation_0-auc:0.81820
# [0]	validation_0-auc:0.80126
# [497]	validation_0-auc:0.81816
# [0]	validation_0-auc:0.81816
# [788]	validation_0-auc:0.81816
# [0]	validation_0-auc:0.80254
# [1000]	validation_0-auc:0.81816
# [1226]	validation_0-auc:0.81817
# [0]	validation_0-auc:0.81817
# [300]	validation_0-auc:0.81816
# [0]	validation_0-auc:0.80339
# [1000]	validation_0-auc:0.81820
# [1962]	validation_0-auc:0.81821
# [0]	validation_0-auc:0.81821
# [304]	validation_0-auc:0.81821
# [0]	validation_0-auc:0.80375
# [885]	validation_0-auc:0.81813
# [0]	validation_0-auc:0.81813
# [485]	validation_0-auc:0.81813
# [0]	validation_0-auc:0.80446
# [1000]	validation_0-auc:0.81821
# [1678]	validation_0-auc:0.81821
# [0]	validation_0-auc:0.81821
# [1000]	validation_0-auc:0.81821
# [1058]	validation_0-auc:0.81821
# [0]	validation_0-auc:0.80492
# [638]	validation_0-auc:0.81817
# [0]	validation_0-auc:0.81817
# [394]	validation_0-auc:0.81817
# fold 4 - xgb auc: 0.818206, elapsed time: 2489.91sec
#
# ===== fold 5 =====
# [0]	validation_0-auc:0.80233
# [1000]	validation_0-auc:0.81556
# [1080]	validation_0-auc:0.81556
# [0]	validation_0-auc:0.81556
# [300]	validation_0-auc:0.81556
# [0]	validation_0-auc:0.80133
# [769]	validation_0-auc:0.81557
# [0]	validation_0-auc:0.81557
# [918]	validation_0-auc:0.81558
# [0]	validation_0-auc:0.80267
# [554]	validation_0-auc:0.81554
# [0]	validation_0-auc:0.81554
# [1000]	validation_0-auc:0.81555
# [1406]	validation_0-auc:0.81555
# [0]	validation_0-auc:0.80246
# [1000]	validation_0-auc:0.81556
# [1388]	validation_0-auc:0.81556
# [0]	validation_0-auc:0.81556
# [543]	validation_0-auc:0.81556
# [0]	validation_0-auc:0.80218
# [990]	validation_0-auc:0.81557
# [0]	validation_0-auc:0.81557
# [418]	validation_0-auc:0.81557
# [0]	validation_0-auc:0.80245
# [595]	validation_0-auc:0.81556
# [0]	validation_0-auc:0.81556
# [752]	validation_0-auc:0.81557
# [0]	validation_0-auc:0.80188
# [1000]	validation_0-auc:0.81557
# [1329]	validation_0-auc:0.81556
# [0]	validation_0-auc:0.81556
# [313]	validation_0-auc:0.81556
# [0]	validation_0-auc:0.80198
# [731]	validation_0-auc:0.81557
# [0]	validation_0-auc:0.81557
# [616]	validation_0-auc:0.81557
# [0]	validation_0-auc:0.80258
# [558]	validation_0-auc:0.81556
# [0]	validation_0-auc:0.81556
# [534]	validation_0-auc:0.81556
# [0]	validation_0-auc:0.80291
# [1000]	validation_0-auc:0.81557
# [1275]	validation_0-auc:0.81557
# [0]	validation_0-auc:0.81557
# [466]	validation_0-auc:0.81557
# [0]	validation_0-auc:0.80197
# [866]	validation_0-auc:0.81554
# [0]	validation_0-auc:0.81554
# [300]	validation_0-auc:0.81554
# [0]	validation_0-auc:0.80210
# [1000]	validation_0-auc:0.81556
# [1028]	validation_0-auc:0.81556
# [0]	validation_0-auc:0.81556
# [303]	validation_0-auc:0.81556
# [0]	validation_0-auc:0.80134
# [830]	validation_0-auc:0.81553
# [0]	validation_0-auc:0.81553
# [1000]	validation_0-auc:0.81554
# [1564]	validation_0-auc:0.81554
# [0]	validation_0-auc:0.80266
# [591]	validation_0-auc:0.81553
# [0]	validation_0-auc:0.81553
# [757]	validation_0-auc:0.81553
# [0]	validation_0-auc:0.80271
# [1000]	validation_0-auc:0.81557
# [1080]	validation_0-auc:0.81557
# [0]	validation_0-auc:0.81557
# [346]	validation_0-auc:0.81557
# [0]	validation_0-auc:0.80148
# [1000]	validation_0-auc:0.81554
# [1246]	validation_0-auc:0.81554
# [0]	validation_0-auc:0.81554
# [523]	validation_0-auc:0.81554
# [0]	validation_0-auc:0.80064
# [1000]	validation_0-auc:0.81556
# [1413]	validation_0-auc:0.81557
# [0]	validation_0-auc:0.81557
# [318]	validation_0-auc:0.81557
# [0]	validation_0-auc:0.80117
# [1000]	validation_0-auc:0.81555
# [1422]	validation_0-auc:0.81554
# [0]	validation_0-auc:0.81554
# [491]	validation_0-auc:0.81554
# [0]	validation_0-auc:0.80139
# [1000]	validation_0-auc:0.81556
# [1541]	validation_0-auc:0.81555
# [0]	validation_0-auc:0.81555
# [313]	validation_0-auc:0.81555
# [0]	validation_0-auc:0.80245
# [1000]	validation_0-auc:0.81558
# [1160]	validation_0-auc:0.81557
# [0]	validation_0-auc:0.81557
# [355]	validation_0-auc:0.81557
# fold 5 - xgb auc: 0.815566, elapsed time: 2124.32sec
#
# ===== fold 6 =====
# [0]	validation_0-auc:0.80479
# [593]	validation_0-auc:0.81952
# [0]	validation_0-auc:0.81952
# [350]	validation_0-auc:0.81952
# [0]	validation_0-auc:0.80421
# [543]	validation_0-auc:0.81954
# [0]	validation_0-auc:0.81954
# [1000]	validation_0-auc:0.81955
# [1739]	validation_0-auc:0.81956
# [0]	validation_0-auc:0.80538
# [524]	validation_0-auc:0.81952
# [0]	validation_0-auc:0.81952
# [634]	validation_0-auc:0.81952
# [0]	validation_0-auc:0.80556
# [524]	validation_0-auc:0.81955
# [0]	validation_0-auc:0.81955
# [300]	validation_0-auc:0.81955
# [0]	validation_0-auc:0.80502
# [926]	validation_0-auc:0.81953
# [0]	validation_0-auc:0.81953
# [403]	validation_0-auc:0.81952
# [0]	validation_0-auc:0.80590
# [551]	validation_0-auc:0.81952
# [0]	validation_0-auc:0.81952
# [540]	validation_0-auc:0.81952
# [0]	validation_0-auc:0.80704
# [569]	validation_0-auc:0.81951
# [0]	validation_0-auc:0.81951
# [1000]	validation_0-auc:0.81952
# [1174]	validation_0-auc:0.81952
# [0]	validation_0-auc:0.80496
# [1000]	validation_0-auc:0.81954
# [1430]	validation_0-auc:0.81952
# [0]	validation_0-auc:0.81952
# [724]	validation_0-auc:0.81953
# [0]	validation_0-auc:0.80408
# [1000]	validation_0-auc:0.81955
# [1360]	validation_0-auc:0.81954
# [0]	validation_0-auc:0.81954
# [864]	validation_0-auc:0.81954
# [0]	validation_0-auc:0.80522
# [508]	validation_0-auc:0.81956
# [0]	validation_0-auc:0.81956
# [642]	validation_0-auc:0.81956
# [0]	validation_0-auc:0.80520
# [1000]	validation_0-auc:0.81956
# [1363]	validation_0-auc:0.81954
# [0]	validation_0-auc:0.81954
# [364]	validation_0-auc:0.81955
# [0]	validation_0-auc:0.80453
# [512]	validation_0-auc:0.81951
# [0]	validation_0-auc:0.81951
# [1000]	validation_0-auc:0.81952
# [1345]	validation_0-auc:0.81952
# [0]	validation_0-auc:0.80514
# [1000]	validation_0-auc:0.81955
# [1362]	validation_0-auc:0.81954
# [0]	validation_0-auc:0.81954
# [425]	validation_0-auc:0.81954
# [0]	validation_0-auc:0.80582
# [849]	validation_0-auc:0.81954
# [0]	validation_0-auc:0.81954
# [439]	validation_0-auc:0.81954
# [0]	validation_0-auc:0.80530
# [1000]	validation_0-auc:0.81954
# [1070]	validation_0-auc:0.81954
# [0]	validation_0-auc:0.81954
# [302]	validation_0-auc:0.81954
# [0]	validation_0-auc:0.80547
# [1000]	validation_0-auc:0.81955
# [1654]	validation_0-auc:0.81954
# [0]	validation_0-auc:0.81954
# [586]	validation_0-auc:0.81954
# [0]	validation_0-auc:0.80693
# [518]	validation_0-auc:0.81951
# [0]	validation_0-auc:0.81951
# [1000]	validation_0-auc:0.81952
# [1023]	validation_0-auc:0.81952
# [0]	validation_0-auc:0.80550
# [479]	validation_0-auc:0.81955
# [0]	validation_0-auc:0.81955
# [1000]	validation_0-auc:0.81956
# [1126]	validation_0-auc:0.81956
# [0]	validation_0-auc:0.80489
# [500]	validation_0-auc:0.81954
# [0]	validation_0-auc:0.81954
# [794]	validation_0-auc:0.81953
# [0]	validation_0-auc:0.80514
# [750]	validation_0-auc:0.81952
# [0]	validation_0-auc:0.81952
# [391]	validation_0-auc:0.81952
# fold 6 - xgb auc: 0.819542, elapsed time: 1999.51sec
#
# ===== fold 7 =====
# [0]	validation_0-auc:0.80156
# [526]	validation_0-auc:0.81568
# [0]	validation_0-auc:0.81569
# [742]	validation_0-auc:0.81569
# [0]	validation_0-auc:0.80234
# [1000]	validation_0-auc:0.81568
# [1121]	validation_0-auc:0.81568
# [0]	validation_0-auc:0.81568
# [299]	validation_0-auc:0.81567
# [0]	validation_0-auc:0.80159
# [761]	validation_0-auc:0.81568
# [0]	validation_0-auc:0.81568
# [933]	validation_0-auc:0.81569
# [0]	validation_0-auc:0.80242
# [1000]	validation_0-auc:0.81570
# [1055]	validation_0-auc:0.81570
# [0]	validation_0-auc:0.81570
# [605]	validation_0-auc:0.81570
# [0]	validation_0-auc:0.80162
# [1000]	validation_0-auc:0.81567
# [1018]	validation_0-auc:0.81567
# [0]	validation_0-auc:0.81567
# [692]	validation_0-auc:0.81568
# [0]	validation_0-auc:0.80137
# [1000]	validation_0-auc:0.81569
# [1925]	validation_0-auc:0.81569
# [0]	validation_0-auc:0.81569
# [702]	validation_0-auc:0.81569
# [0]	validation_0-auc:0.80228
# [859]	validation_0-auc:0.81566
# [0]	validation_0-auc:0.81566
# [782]	validation_0-auc:0.81566
# [0]	validation_0-auc:0.80161
# [521]	validation_0-auc:0.81569
# [0]	validation_0-auc:0.81569
# [371]	validation_0-auc:0.81569
# [0]	validation_0-auc:0.80248
# [654]	validation_0-auc:0.81570
# [0]	validation_0-auc:0.81571
# [390]	validation_0-auc:0.81571
# [0]	validation_0-auc:0.80165
# [871]	validation_0-auc:0.81571
# [0]	validation_0-auc:0.81571
# [652]	validation_0-auc:0.81572
# [0]	validation_0-auc:0.80131
# [1000]	validation_0-auc:0.81571
# [1262]	validation_0-auc:0.81569
# [0]	validation_0-auc:0.81569
# [1000]	validation_0-auc:0.81570
# [1155]	validation_0-auc:0.81570
# [0]	validation_0-auc:0.80237
# [542]	validation_0-auc:0.81568
# [0]	validation_0-auc:0.81568
# [314]	validation_0-auc:0.81568
# [0]	validation_0-auc:0.80145
# [872]	validation_0-auc:0.81566
# [0]	validation_0-auc:0.81566
# [429]	validation_0-auc:0.81566
# [0]	validation_0-auc:0.80129
# [1000]	validation_0-auc:0.81567
# [1086]	validation_0-auc:0.81567
# [0]	validation_0-auc:0.81567
# [633]	validation_0-auc:0.81567
# [0]	validation_0-auc:0.80222
# [469]	validation_0-auc:0.81565
# [0]	validation_0-auc:0.81565
# [720]	validation_0-auc:0.81566
# [0]	validation_0-auc:0.80146
# [1000]	validation_0-auc:0.81569
# [1316]	validation_0-auc:0.81569
# [0]	validation_0-auc:0.81569
# [507]	validation_0-auc:0.81569
# [0]	validation_0-auc:0.80223
# [963]	validation_0-auc:0.81566
# [0]	validation_0-auc:0.81566
# [405]	validation_0-auc:0.81566
# [0]	validation_0-auc:0.80081
# [982]	validation_0-auc:0.81567
# [0]	validation_0-auc:0.81567
# [660]	validation_0-auc:0.81567
# [0]	validation_0-auc:0.80051
# [940]	validation_0-auc:0.81566
# [0]	validation_0-auc:0.81566
# [384]	validation_0-auc:0.81565
# [0]	validation_0-auc:0.80234
# [1000]	validation_0-auc:0.81568
# [1607]	validation_0-auc:0.81569
# [0]	validation_0-auc:0.81569
# [299]	validation_0-auc:0.81569
# fold 7 - xgb auc: 0.815690, elapsed time: 2056.66sec
#
# ===== fold 8 =====
# [0]	validation_0-auc:0.80365
# [690]	validation_0-auc:0.81727
# [0]	validation_0-auc:0.81727
# [309]	validation_0-auc:0.81727
# [0]	validation_0-auc:0.80335
# [470]	validation_0-auc:0.81724
# [0]	validation_0-auc:0.81724
# [393]	validation_0-auc:0.81724
# [0]	validation_0-auc:0.80329
# [420]	validation_0-auc:0.81727
# [0]	validation_0-auc:0.81727
# [320]	validation_0-auc:0.81726
# [0]	validation_0-auc:0.80195
# [570]	validation_0-auc:0.81730
# [0]	validation_0-auc:0.81730
# [448]	validation_0-auc:0.81730
# [0]	validation_0-auc:0.80247
# [450]	validation_0-auc:0.81727
# [0]	validation_0-auc:0.81727
# [551]	validation_0-auc:0.81728
# [0]	validation_0-auc:0.80335
# [628]	validation_0-auc:0.81727
# [0]	validation_0-auc:0.81727
# [318]	validation_0-auc:0.81727
# [0]	validation_0-auc:0.80235
# [1000]	validation_0-auc:0.81724
# [1031]	validation_0-auc:0.81724
# [0]	validation_0-auc:0.81724
# [316]	validation_0-auc:0.81724
# [0]	validation_0-auc:0.80371
# [564]	validation_0-auc:0.81724
# [0]	validation_0-auc:0.81724
# [475]	validation_0-auc:0.81724
# [0]	validation_0-auc:0.80320
# [530]	validation_0-auc:0.81725
# [0]	validation_0-auc:0.81725
# [773]	validation_0-auc:0.81726
# [0]	validation_0-auc:0.80366
# [740]	validation_0-auc:0.81721
# [0]	validation_0-auc:0.81721
# [438]	validation_0-auc:0.81721
# [0]	validation_0-auc:0.80268
# [455]	validation_0-auc:0.81722
# [0]	validation_0-auc:0.81722
# [313]	validation_0-auc:0.81722
# [0]	validation_0-auc:0.80279
# [851]	validation_0-auc:0.81726
# [0]	validation_0-auc:0.81726
# [986]	validation_0-auc:0.81726
# [0]	validation_0-auc:0.80237
# [491]	validation_0-auc:0.81725
# [0]	validation_0-auc:0.81725
# [299]	validation_0-auc:0.81725
# [0]	validation_0-auc:0.80355
# [576]	validation_0-auc:0.81723
# [0]	validation_0-auc:0.81723
# [299]	validation_0-auc:0.81723
# [0]	validation_0-auc:0.80080
# [606]	validation_0-auc:0.81727
# [0]	validation_0-auc:0.81727
# [562]	validation_0-auc:0.81727
# [0]	validation_0-auc:0.80371
# [701]	validation_0-auc:0.81728
# [0]	validation_0-auc:0.81728
# [442]	validation_0-auc:0.81728
# [0]	validation_0-auc:0.80241
# [513]	validation_0-auc:0.81727
# [0]	validation_0-auc:0.81727
# [737]	validation_0-auc:0.81727
# [0]	validation_0-auc:0.80336
# [566]	validation_0-auc:0.81723
# [0]	validation_0-auc:0.81723
# [309]	validation_0-auc:0.81723
# [0]	validation_0-auc:0.80370
# [637]	validation_0-auc:0.81726
# [0]	validation_0-auc:0.81726
# [482]	validation_0-auc:0.81726
# [0]	validation_0-auc:0.80385
# [709]	validation_0-auc:0.81726
# [0]	validation_0-auc:0.81726
# [480]	validation_0-auc:0.81726
# fold 8 - xgb auc: 0.817262, elapsed time: 1413.75sec
#
# ===== fold 9 =====
# [0]	validation_0-auc:0.80292
# [582]	validation_0-auc:0.81643
# [0]	validation_0-auc:0.81643
# [1000]	validation_0-auc:0.81644
# [1467]	validation_0-auc:0.81644
# [0]	validation_0-auc:0.80168
# [1000]	validation_0-auc:0.81644
# [1059]	validation_0-auc:0.81643
# [0]	validation_0-auc:0.81643
# [305]	validation_0-auc:0.81643
# [0]	validation_0-auc:0.80267
# [654]	validation_0-auc:0.81646
# [0]	validation_0-auc:0.81646
# [332]	validation_0-auc:0.81646
# [0]	validation_0-auc:0.80262
# [934]	validation_0-auc:0.81643
# [0]	validation_0-auc:0.81643
# [373]	validation_0-auc:0.81643
# [0]	validation_0-auc:0.80088
# [497]	validation_0-auc:0.81641
# [0]	validation_0-auc:0.81641
# [1000]	validation_0-auc:0.81641
# [1059]	validation_0-auc:0.81642
# [0]	validation_0-auc:0.80251
# [701]	validation_0-auc:0.81644
# [0]	validation_0-auc:0.81644
# [299]	validation_0-auc:0.81644
# [0]	validation_0-auc:0.80202
# [922]	validation_0-auc:0.81641
# [0]	validation_0-auc:0.81641
# [310]	validation_0-auc:0.81641
# [0]	validation_0-auc:0.80106
# [808]	validation_0-auc:0.81644
# [0]	validation_0-auc:0.81644
# [324]	validation_0-auc:0.81644
# [0]	validation_0-auc:0.80095
# [725]	validation_0-auc:0.81645
# [0]	validation_0-auc:0.81645
# [733]	validation_0-auc:0.81646
# [0]	validation_0-auc:0.80097
# [669]	validation_0-auc:0.81643
# [0]	validation_0-auc:0.81643
# [1000]	validation_0-auc:0.81644
# [1022]	validation_0-auc:0.81643
# [0]	validation_0-auc:0.80160
# [1000]	validation_0-auc:0.81649
# [1271]	validation_0-auc:0.81647
# [0]	validation_0-auc:0.81647
# [477]	validation_0-auc:0.81647
# [0]	validation_0-auc:0.80157
# [1000]	validation_0-auc:0.81646
# [1133]	validation_0-auc:0.81646
# [0]	validation_0-auc:0.81646
# [574]	validation_0-auc:0.81646
# [0]	validation_0-auc:0.80145
# [596]	validation_0-auc:0.81641
# [0]	validation_0-auc:0.81641
# [343]	validation_0-auc:0.81641
# [0]	validation_0-auc:0.80197
# [916]	validation_0-auc:0.81649
# [0]	validation_0-auc:0.81649
# [490]	validation_0-auc:0.81649
# [0]	validation_0-auc:0.80276
# [900]	validation_0-auc:0.81645
# [0]	validation_0-auc:0.81645
# [346]	validation_0-auc:0.81644
# [0]	validation_0-auc:0.80190
# [993]	validation_0-auc:0.81640
# [0]	validation_0-auc:0.81640
# [418]	validation_0-auc:0.81640
# [0]	validation_0-auc:0.80151
# [1000]	validation_0-auc:0.81647
# [1346]	validation_0-auc:0.81647
# [0]	validation_0-auc:0.81647
# [334]	validation_0-auc:0.81647
# [0]	validation_0-auc:0.80075
# [516]	validation_0-auc:0.81644
# [0]	validation_0-auc:0.81644
# [1000]	validation_0-auc:0.81645
# [1186]	validation_0-auc:0.81644
# [0]	validation_0-auc:0.80200
# [1000]	validation_0-auc:0.81644
# [1002]	validation_0-auc:0.81644
# [0]	validation_0-auc:0.81644
# [396]	validation_0-auc:0.81644
# [0]	validation_0-auc:0.80183
# [1000]	validation_0-auc:0.81643
# [1014]	validation_0-auc:0.81643
# [0]	validation_0-auc:0.81643
# [435]	validation_0-auc:0.81643
# fold 9 - xgb auc: 0.816457, elapsed time: 1827.68sec
#
# oof xgb_auc = 0.8170173357474632

# %% [markdown]
# # OOF predictions

# %%
plt.plot(train[target], train[target])
plt.scatter(train[target], xgb_oof)

# %% [markdown]
# # Features importances

# %%
order = list(xgb_importances.groupby('feature').mean().sort_values('importance', ascending=False).index)

fig = plt.figure(figsize=(16, 16), tight_layout=True)
sns.barplot(x="importance", y="feature", data=xgb_importances.groupby('feature').mean().reset_index(), order=order)
plt.title("LightGBM feature importances")
# Out:
# Text(0.5, 1.0, 'LightGBM feature importances')

# %% [markdown]
# # Submission

# %%
submission[target] = xgb_pred
submission.to_csv("submission.csv", index=False)

submission
# Out:
#              id     claim
# 0        957919  0.569610
# 1        957920  0.122720
# 2        957921  0.627649
# 3        957922  0.128085
# 4        957923  0.157738
# ...         ...       ...
# 493469  1451388  0.831848
# 493470  1451389  0.110959
# 493471  1451390  0.775066
# 493472  1451391  0.130700
# 493473  1451392  0.753426
#
# [493474 rows x 2 columns]

# %% [markdown]
# # Log
#
# /////// 8 trees + ridge /////////
