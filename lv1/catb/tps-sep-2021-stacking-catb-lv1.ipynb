# %%
import numpy as np
import pandas as pd
import random
import os
import time
import pickle
from pathlib import Path

from sklearn.preprocessing import StandardScaler, QuantileTransformer
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import roc_auc_score

#import lightgbm as lgb
#import xgboost as xgb
import catboost as ctb

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# # Parameters

# %%
target = 'claim'

DEBUG = False

if DEBUG:
    N_ESTIMATORS = 1
    N_SPLITS = 2
    SEED = 2017
    CVSEED = 2017
    EARLY_STOPPING_ROUNDS = 1
    VERBOSE = 100
    #N_ITERS = 2
else:
    N_SPLITS = 10
    N_ESTIMATORS = 20000
    EARLY_STOPPING_ROUNDS = 300
    VERBOSE = 1000
    SEED = 2017
    CVSEED = 2017
    #N_ITERS = 10

# %%
def set_seed(seed=2017):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    
set_seed(SEED)

# %% [markdown]
# # Datasets

# %%
INPUT = Path("../input/tabular-playground-series-sep-2021")

train = pd.DataFrame(pd.read_csv(INPUT / "train.csv")[target])
#test = pd.read_csv(INPUT / "test.csv")
test = pd.DataFrame()
submission = pd.read_csv(INPUT / "sample_solution.csv")

# %%
train['lgb_pred'] = np.load("../input/tps-sep-lv0-base-trees/agg_lgb_oof.npy")
test['lgb_pred'] = np.load("../input/tps-sep-lv0-base-trees/agg_lgb_pred.npy")

train['lgb2_pred'] = np.load("../input/tps-sep-lv0-base-trees/agg_lgb2_oof.npy")
test['lgb2_pred'] = np.load("../input/tps-sep-lv0-base-trees/agg_lgb2_pred.npy")

train['xgb_pred'] = np.load("../input/tps-sep-lv0-base-trees/agg_xgb_oof.npy")
test['xgb_pred'] = np.load("../input/tps-sep-lv0-base-trees/agg_xgb_pred.npy")

train['lgb_bizen_pred'] = np.load("../input/tps-sep-lv0-base-trees/lgb_bizen_oof.npy")
test['lgb_bizen_pred'] = np.load("../input/tps-sep-lv0-base-trees/lgb_bizen_pred.npy")

train['lgb_dmitry_pred'] = np.load("../input/tps-sep-lv0-base-trees/lgb_dmitry_oof.npy")
test['lgb_dmitry_pred'] = np.load("../input/tps-sep-lv0-base-trees/lgb_dmitry_pred.npy")

train['xgb_dmitry_pred'] = np.load("../input/tps-sep-lv0-base-trees/xgb_dmitry_oof.npy")
test['xgb_dmitry_pred'] = np.load("../input/tps-sep-lv0-base-trees/xgb_dmitry_pred.npy")

train['lgb_manav_pred'] = np.load("../input/tps-sep-lv0-base-trees/lgb_manav_oof.npy")
test['lgb_manav_pred'] = np.load("../input/tps-sep-lv0-base-trees/lgb_manav_pred.npy")

train['xgb_manav_pred'] = np.load("../input/tps-sep-lv0-base-trees/xgb_manav_oof.npy")
test['xgb_manav_pred'] = np.load("../input/tps-sep-lv0-base-trees/xgb_manav_pred.npy")

# %%
train['ridge_pred'] = np.load("../input/tps-sep-lv0-base-trees/ridge_oof.npy")
test['ridge_pred'] = np.load("../input/tps-sep-lv0-base-trees/ridge_pred.npy")

# %% [markdown]
# # Preprocessing

# %%
features = [col for col in train.columns if 'pred' in col]

# %%
ss = StandardScaler()

# %%
test[features]
# Out:
#         lgb_pred  lgb2_pred  xgb_pred  lgb_bizen_pred  lgb_dmitry_pred  \
# 0       0.558734   0.578699  0.576973        0.561836         0.566536
# 1       0.130124   0.120648  0.124073        0.119917         0.126946
# 2       0.634854   0.628457  0.630655        0.629326         0.627686
# 3       0.121661   0.125785  0.126651        0.128635         0.122506
# 4       0.151700   0.150161  0.149483        0.153291         0.146343
# ...          ...        ...       ...             ...              ...
# 493469  0.833647   0.829336  0.829659        0.827457         0.825696
# 493470  0.114116   0.116351  0.117947        0.111374         0.112238
# 493471  0.771955   0.760704  0.758474        0.758873         0.764026
# 493472  0.129603   0.132275  0.129645        0.133944         0.135123
# 493473  0.742763   0.748962  0.749504        0.757657         0.744380
#
#         xgb_dmitry_pred  lgb_manav_pred  xgb_manav_pred  ridge_pred
# 0              0.575204        0.564575        0.564908    0.553440
# 1              0.126340        0.121656        0.120459    0.182040
# 2              0.635330        0.626681        0.633499    0.631720
# 3              0.123506        0.128684        0.131022    0.184237
# 4              0.143437        0.152862        0.153132    0.203202
# ...                 ...             ...             ...         ...
# 493469         0.827184        0.831222        0.816129    0.790480
# 493470         0.115928        0.111981        0.109487    0.174385
# 493471         0.754300        0.756039        0.774203    0.751130
# 493472         0.132036        0.135098        0.136081    0.184900
# 493473         0.747717        0.741040        0.760795    0.734600
#
# [493474 rows x 9 columns]

# %%
train[target]
# Out:
# 0         1
# 1         0
# 2         1
# 3         1
# 4         1
#          ..
# 957914    0
# 957915    1
# 957916    0
# 957917    1
# 957918    0
# Name: claim, Length: 957919, dtype: int64

# %% [markdown]
# # CatB

# %%
ctb_params = {
           'objective': 'CrossEntropy',                
                      'n_estimators':N_ESTIMATORS,                 
                      'thread_count' : -1,              
                      'bootstrap_type': 'Bernoulli',             
                      'eval_metric': 'AUC',       
      
                      'learning_rate': 0.043247254815977625,
                     'subsample': 0.858236387817822,
                     'colsample_bylevel': 0.8251700859011009,
                     'max_depth': 3,
                     'min_child_samples': 215,
                     'max_bin': 334,
                     'reg_lambda': 0.009255003723049078,
                     'random_strength': 20.306086483358612
}

# %%
ctb_oof = np.zeros(train.shape[0])
ctb_pred = np.zeros(test.shape[0])
ctb_importances = pd.DataFrame()


kf = StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=CVSEED)
seed_list=range(SEED, SEED+10)

for fold, (trn_idx, val_idx) in enumerate(kf.split(X=train[features], y=train[target])):
    print(f"===== fold {fold} =====")


    X_train = train[features].iloc[trn_idx]
    y_train = train[target].iloc[trn_idx]
    X_valid = train[features].iloc[val_idx]
    y_valid = train[target].iloc[val_idx]
    X_test = test[features]
      
        
    X_train[features] = ss.fit_transform(X_train[features])
    X_valid[features] = ss.transform(X_valid[features])
    X_test[features] = ss.transform(X_test[features])

    start = time.time()
    for inseed in seed_list:
        ctb_params['random_state'] = inseed

        pre_model = ctb.CatBoostClassifier(**ctb_params)
        pre_model.fit(
            X_train, 
            y_train,
            eval_set=[(X_valid, y_valid)],
            use_best_model=True,
            early_stopping_rounds=EARLY_STOPPING_ROUNDS,
            verbose=VERBOSE,
        )

        ctb_params2 = ctb_params.copy()
        ctb_params2['reg_lambda'] *= 0.9
        #ctb_params2['reg_alpha'] *= 0.9
        ctb_params2['learning_rate'] *= 0.1
        model = ctb.CatBoostClassifier(**ctb_params2)
        model.fit(
                X_train, y_train,
                eval_set=[(X_valid, y_valid)],
                use_best_model=True,
                early_stopping_rounds=EARLY_STOPPING_ROUNDS,
                verbose=VERBOSE,
                init_model=pre_model
        )    

        with open(f"ctb_model{fold}_seed{inseed}.pkl", 'wb') as f:
            pickle.dump(model, f)

        fi_tmp = pd.DataFrame()
        fi_tmp['feature'] = X_train.columns
        fi_tmp['importance'] = model.feature_importances_
        fi_tmp['fold'] = fold
        fi_tmp['seed'] = inseed
        ctb_importances = ctb_importances.append(fi_tmp)

        ctb_oof[val_idx] += model.predict_proba(X_valid)[:,-1] / len(seed_list)
        ctb_pred += model.predict_proba(X_test)[:,-1] / len(seed_list)


    elapsed = time.time() - start
    auc = roc_auc_score(y_valid, ctb_oof[val_idx])
    print(f"fold {fold} - ctb auc: {auc:.6f}, elapsed time: {elapsed:.2f}sec\n")            

ctb_pred /= N_SPLITS
print(f"oof ctb_auc = {roc_auc_score(train[target], ctb_oof)}")

np.save("ctb_oof.npy", ctb_oof)
np.save("ctb_pred.npy", ctb_pred)
# Out:
# ===== fold 0 =====
# 0:	test: 0.8049433	best: 0.8049433 (0)	total: 192ms	remaining: 1h 3m 51s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.817235751
# bestIteration = 611
#
# Shrink model to first 612 iterations.
# 0:	test: 0.8172358	best: 0.8172358 (0)	total: 113ms	remaining: 37m 31s
# 1000:	test: 0.8172389	best: 0.8172390 (988)	total: 1m 57s	remaining: 37m 1s
# 2000:	test: 0.8172412	best: 0.8172423 (1766)	total: 3m 55s	remaining: 35m 15s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8172422684
# bestIteration = 1766
#
# Shrink model to first 1767 iterations.
# 0:	test: 0.8030489	best: 0.8030489 (0)	total: 132ms	remaining: 44m 6s
# 1000:	test: 0.8173093	best: 0.8173364 (764)	total: 2m 8s	remaining: 40m 32s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8173363985
# bestIteration = 764
#
# Shrink model to first 765 iterations.
# 0:	test: 0.8173364	best: 0.8173364 (0)	total: 115ms	remaining: 38m 19s
# 1000:	test: 0.8173385	best: 0.8173391 (835)	total: 1m 57s	remaining: 37m 16s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8173391334
# bestIteration = 835
#
# Shrink model to first 836 iterations.
# 0:	test: 0.8045726	best: 0.8045726 (0)	total: 120ms	remaining: 39m 59s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8172609737
# bestIteration = 525
#
# Shrink model to first 526 iterations.
# 0:	test: 0.8172609	best: 0.8172609 (0)	total: 117ms	remaining: 38m 59s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8172615129
# bestIteration = 132
#
# Shrink model to first 133 iterations.
# 0:	test: 0.7895322	best: 0.7895322 (0)	total: 123ms	remaining: 41m 5s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.817253694
# bestIteration = 545
#
# Shrink model to first 546 iterations.
# 0:	test: 0.8172537	best: 0.8172537 (0)	total: 117ms	remaining: 38m 50s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8172539578
# bestIteration = 26
#
# Shrink model to first 27 iterations.
# 0:	test: 0.7902513	best: 0.7902513 (0)	total: 122ms	remaining: 40m 49s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.81730146
# bestIteration = 674
#
# Shrink model to first 675 iterations.
# 0:	test: 0.8173015	best: 0.8173015 (0)	total: 137ms	remaining: 45m 45s
# 1000:	test: 0.8173046	best: 0.8173051 (861)	total: 1m 56s	remaining: 36m 55s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8173051041
# bestIteration = 861
#
# Shrink model to first 862 iterations.
# 0:	test: 0.7831605	best: 0.7831605 (0)	total: 117ms	remaining: 38m 56s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8172713341
# bestIteration = 595
#
# Shrink model to first 596 iterations.
# 0:	test: 0.8172713	best: 0.8172713 (0)	total: 117ms	remaining: 39m 4s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8172719418
# bestIteration = 46
#
# Shrink model to first 47 iterations.
# 0:	test: 0.7856402	best: 0.7856402 (0)	total: 120ms	remaining: 39m 50s
# 1000:	test: 0.8172383	best: 0.8172525 (713)	total: 2m 6s	remaining: 39m 56s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8172524641
# bestIteration = 713
#
# Shrink model to first 714 iterations.
# 0:	test: 0.8172523	best: 0.8172523 (0)	total: 115ms	remaining: 38m 26s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8172523677
# bestIteration = 10
#
# Shrink model to first 11 iterations.
# 0:	test: 0.8042903	best: 0.8042903 (0)	total: 126ms	remaining: 41m 50s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8172769592
# bestIteration = 613
#
# Shrink model to first 614 iterations.
# 0:	test: 0.8172770	best: 0.8172770 (0)	total: 110ms	remaining: 36m 34s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8172778389
# bestIteration = 299
#
# Shrink model to first 300 iterations.
# 0:	test: 0.8021287	best: 0.8021287 (0)	total: 123ms	remaining: 40m 54s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8172205226
# bestIteration = 650
#
# Shrink model to first 651 iterations.
# 0:	test: 0.8172205	best: 0.8172205 (0)	total: 116ms	remaining: 38m 40s
# 1000:	test: 0.8172234	best: 0.8172234 (998)	total: 1m 58s	remaining: 37m 21s
# 2000:	test: 0.8172252	best: 0.8172265 (1703)	total: 3m 55s	remaining: 35m 19s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8172265448
# bestIteration = 1703
#
# Shrink model to first 1704 iterations.
# 0:	test: 0.7909700	best: 0.7909700 (0)	total: 127ms	remaining: 42m 11s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8172304569
# bestIteration = 69
#
# Shrink model to first 70 iterations.
# 0:	test: 0.8172266	best: 0.8172266 (0)	total: 126ms	remaining: 41m 54s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8172294219
# bestIteration = 151
#
# Shrink model to first 152 iterations.
# fold 0 - ctb auc: 0.817318, elapsed time: 2156.14sec
#
# ===== fold 1 =====
# 0:	test: 0.8027645	best: 0.8027645 (0)	total: 123ms	remaining: 41m 5s
# 1000:	test: 0.8162669	best: 0.8162682 (969)	total: 2m 5s	remaining: 39m 38s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8162742879
# bestIteration = 1049
#
# Shrink model to first 1050 iterations.
# 0:	test: 0.8162743	best: 0.8162743 (0)	total: 118ms	remaining: 39m 21s
# 1000:	test: 0.8162760	best: 0.8162761 (983)	total: 1m 59s	remaining: 37m 40s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8162762779
# bestIteration = 1153
#
# Shrink model to first 1154 iterations.
# 0:	test: 0.8025228	best: 0.8025228 (0)	total: 127ms	remaining: 42m 15s
# 1000:	test: 0.8161872	best: 0.8161962 (940)	total: 2m 8s	remaining: 40m 39s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8161961853
# bestIteration = 940
#
# Shrink model to first 941 iterations.
# 0:	test: 0.8161962	best: 0.8161962 (0)	total: 116ms	remaining: 38m 49s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.816196507
# bestIteration = 104
#
# Shrink model to first 105 iterations.
# 0:	test: 0.8045316	best: 0.8045316 (0)	total: 124ms	remaining: 41m 14s
# 1000:	test: 0.8162066	best: 0.8162298 (876)	total: 2m 7s	remaining: 40m 26s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8162297774
# bestIteration = 876
#
# Shrink model to first 877 iterations.
# 0:	test: 0.8162298	best: 0.8162298 (0)	total: 113ms	remaining: 37m 39s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8162301521
# bestIteration = 21
#
# Shrink model to first 22 iterations.
# 0:	test: 0.7896134	best: 0.7896134 (0)	total: 118ms	remaining: 39m 23s
# 1000:	test: 0.8161466	best: 0.8161466 (1000)	total: 2m 4s	remaining: 39m 25s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8162075473
# bestIteration = 1320
#
# Shrink model to first 1321 iterations.
# 0:	test: 0.8162076	best: 0.8162076 (0)	total: 111ms	remaining: 36m 52s
# 1000:	test: 0.8162095	best: 0.8162100 (899)	total: 1m 57s	remaining: 37m 9s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8162100019
# bestIteration = 899
#
# Shrink model to first 900 iterations.
# 0:	test: 0.7971046	best: 0.7971046 (0)	total: 186ms	remaining: 1h 1m 56s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8162977574
# bestIteration = 662
#
# Shrink model to first 663 iterations.
# 0:	test: 0.8162978	best: 0.8162978 (0)	total: 116ms	remaining: 38m 34s
# 1000:	test: 0.8163010	best: 0.8163011 (990)	total: 1m 57s	remaining: 37m 3s
# 2000:	test: 0.8163037	best: 0.8163037 (1993)	total: 3m 54s	remaining: 35m 12s
# 3000:	test: 0.8163061	best: 0.8163062 (2980)	total: 5m 54s	remaining: 33m 28s
# 4000:	test: 0.8163115	best: 0.8163115 (4000)	total: 7m 56s	remaining: 31m 44s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8163138181
# bestIteration = 4049
#
# Shrink model to first 4050 iterations.
# 0:	test: 0.7816642	best: 0.7816642 (0)	total: 125ms	remaining: 41m 47s
# 1000:	test: 0.8162730	best: 0.8162943 (961)	total: 2m 7s	remaining: 40m 19s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8162942792
# bestIteration = 961
#
# Shrink model to first 962 iterations.
# 0:	test: 0.8162941	best: 0.8162941 (0)	total: 117ms	remaining: 38m 58s
# 1000:	test: 0.8162967	best: 0.8162968 (975)	total: 1m 58s	remaining: 37m 23s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8162978428
# bestIteration = 1449
#
# Shrink model to first 1450 iterations.
# 0:	test: 0.7802878	best: 0.7802878 (0)	total: 130ms	remaining: 43m 23s
# 1000:	test: 0.8162328	best: 0.8162446 (853)	total: 2m 4s	remaining: 39m 24s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8162445631
# bestIteration = 853
#
# Shrink model to first 854 iterations.
# 0:	test: 0.8162446	best: 0.8162446 (0)	total: 116ms	remaining: 38m 47s
# 1000:	test: 0.8162495	best: 0.8162495 (987)	total: 2m 1s	remaining: 38m 16s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8162512895
# bestIteration = 1659
#
# Shrink model to first 1660 iterations.
# 0:	test: 0.8015636	best: 0.8015636 (0)	total: 135ms	remaining: 44m 50s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8162410038
# bestIteration = 697
#
# Shrink model to first 698 iterations.
# 0:	test: 0.8162410	best: 0.8162410 (0)	total: 116ms	remaining: 38m 33s
# 1000:	test: 0.8162433	best: 0.8162434 (852)	total: 1m 57s	remaining: 37m 8s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8162433818
# bestIteration = 852
#
# Shrink model to first 853 iterations.
# 0:	test: 0.8001779	best: 0.8001779 (0)	total: 122ms	remaining: 40m 47s
# 1000:	test: 0.8162476	best: 0.8162721 (967)	total: 2m 3s	remaining: 39m 11s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8162720597
# bestIteration = 967
#
# Shrink model to first 968 iterations.
# 0:	test: 0.8162721	best: 0.8162721 (0)	total: 163ms	remaining: 54m 10s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8162728684
# bestIteration = 234
#
# Shrink model to first 235 iterations.
# 0:	test: 0.7877323	best: 0.7877323 (0)	total: 121ms	remaining: 40m 21s
# 1000:	test: 0.8162175	best: 0.8162343 (940)	total: 2m 3s	remaining: 39m 11s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8162342937
# bestIteration = 940
#
# Shrink model to first 941 iterations.
# 0:	test: 0.8162342	best: 0.8162342 (0)	total: 144ms	remaining: 48m 1s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8162342891
# bestIteration = 9
#
# Shrink model to first 10 iterations.
# fold 1 - ctb auc: 0.816305, elapsed time: 3165.90sec
#
# ===== fold 2 =====
# 0:	test: 0.8044377	best: 0.8044377 (0)	total: 119ms	remaining: 39m 37s
# 1000:	test: 0.8179083	best: 0.8179085 (878)	total: 2m 3s	remaining: 39m 2s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8179104078
# bestIteration = 1010
#
# Shrink model to first 1011 iterations.
# 0:	test: 0.8179104	best: 0.8179104 (0)	total: 115ms	remaining: 38m 13s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8179105445
# bestIteration = 3
#
# Shrink model to first 4 iterations.
# 0:	test: 0.8036435	best: 0.8036435 (0)	total: 122ms	remaining: 40m 44s
# 1000:	test: 0.8177888	best: 0.8177996 (866)	total: 2m 4s	remaining: 39m 22s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8177995568
# bestIteration = 866
#
# Shrink model to first 867 iterations.
# 0:	test: 0.8177996	best: 0.8177996 (0)	total: 118ms	remaining: 39m 22s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8177999129
# bestIteration = 165
#
# Shrink model to first 166 iterations.
# 0:	test: 0.8041397	best: 0.8041397 (0)	total: 126ms	remaining: 41m 55s
# 1000:	test: 0.8177452	best: 0.8177828 (720)	total: 2m 5s	remaining: 39m 39s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8177827792
# bestIteration = 720
#
# Shrink model to first 721 iterations.
# 0:	test: 0.8177828	best: 0.8177828 (0)	total: 113ms	remaining: 37m 46s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8177830163
# bestIteration = 48
#
# Shrink model to first 49 iterations.
# 0:	test: 0.7919382	best: 0.7919382 (0)	total: 125ms	remaining: 41m 41s
# 1000:	test: 0.8178093	best: 0.8178155 (909)	total: 2m 3s	remaining: 39m 10s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8178297755
# bestIteration = 1243
#
# Shrink model to first 1244 iterations.
# 0:	test: 0.8178297	best: 0.8178297 (0)	total: 118ms	remaining: 39m 15s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8178298357
# bestIteration = 40
#
# Shrink model to first 41 iterations.
# 0:	test: 0.7970114	best: 0.7970114 (0)	total: 125ms	remaining: 41m 39s
# 1000:	test: 0.8177035	best: 0.8177211 (896)	total: 2m 6s	remaining: 39m 59s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8177210664
# bestIteration = 896
#
# Shrink model to first 897 iterations.
# 0:	test: 0.8177211	best: 0.8177211 (0)	total: 132ms	remaining: 44m 8s
# 1000:	test: 0.8177241	best: 0.8177243 (970)	total: 1m 58s	remaining: 37m 37s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.817724302
# bestIteration = 970
#
# Shrink model to first 971 iterations.
# 0:	test: 0.7830143	best: 0.7830143 (0)	total: 125ms	remaining: 41m 49s
# 1000:	test: 0.8177818	best: 0.8177885 (972)	total: 2m 3s	remaining: 39m 5s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.817788506
# bestIteration = 972
#
# Shrink model to first 973 iterations.
# 0:	test: 0.8177885	best: 0.8177885 (0)	total: 120ms	remaining: 40m 3s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8177896878
# bestIteration = 531
#
# Shrink model to first 532 iterations.
# 0:	test: 0.7830080	best: 0.7830080 (0)	total: 117ms	remaining: 39m 3s
# 1000:	test: 0.8177409	best: 0.8177624 (838)	total: 2m 3s	remaining: 39m 10s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8177624309
# bestIteration = 838
#
# Shrink model to first 839 iterations.
# 0:	test: 0.8177624	best: 0.8177624 (0)	total: 116ms	remaining: 38m 49s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8177624109
# bestIteration = 0
#
# Shrink model to first 1 iterations.
# 0:	test: 0.8041156	best: 0.8041156 (0)	total: 117ms	remaining: 38m 51s
# 1000:	test: 0.8178243	best: 0.8178441 (929)	total: 2m 4s	remaining: 39m 17s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8178441332
# bestIteration = 929
#
# Shrink model to first 930 iterations.
# 0:	test: 0.8178441	best: 0.8178441 (0)	total: 110ms	remaining: 36m 37s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8178446155
# bestIteration = 173
#
# Shrink model to first 174 iterations.
# 0:	test: 0.8019110	best: 0.8019110 (0)	total: 123ms	remaining: 40m 51s
# 1000:	test: 0.8178610	best: 0.8178630 (806)	total: 2m 3s	remaining: 39m 4s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.817868168
# bestIteration = 1007
#
# Shrink model to first 1008 iterations.
# 0:	test: 0.8178682	best: 0.8178682 (0)	total: 114ms	remaining: 37m 54s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8178682935
# bestIteration = 13
#
# Shrink model to first 14 iterations.
# 0:	test: 0.7913705	best: 0.7913705 (0)	total: 120ms	remaining: 39m 57s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8177442716
# bestIteration = 633
#
# Shrink model to first 634 iterations.
# 0:	test: 0.8177443	best: 0.8177443 (0)	total: 110ms	remaining: 36m 40s
# 1000:	test: 0.8177495	best: 0.8177496 (995)	total: 1m 57s	remaining: 37m 10s
# 2000:	test: 0.8177521	best: 0.8177523 (1901)	total: 3m 57s	remaining: 35m 39s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8177523159
# bestIteration = 1901
#
# Shrink model to first 1902 iterations.
# fold 2 - ctb auc: 0.817855, elapsed time: 2341.34sec
#
# ===== fold 3 =====
# 0:	test: 0.8042756	best: 0.8042756 (0)	total: 121ms	remaining: 40m 12s
# 1000:	test: 0.8163019	best: 0.8163480 (772)	total: 2m 4s	remaining: 39m 22s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8163479752
# bestIteration = 772
#
# Shrink model to first 773 iterations.
# 0:	test: 0.8163480	best: 0.8163480 (0)	total: 114ms	remaining: 38m 3s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8163484802
# bestIteration = 269
#
# Shrink model to first 270 iterations.
# 0:	test: 0.8009304	best: 0.8009304 (0)	total: 120ms	remaining: 39m 57s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8164375687
# bestIteration = 565
#
# Shrink model to first 566 iterations.
# 0:	test: 0.8164376	best: 0.8164376 (0)	total: 118ms	remaining: 39m 21s
# 1000:	test: 0.8164392	best: 0.8164393 (911)	total: 2m 2s	remaining: 38m 37s
# 2000:	test: 0.8164440	best: 0.8164441 (1996)	total: 4m	remaining: 36m 6s
# 3000:	test: 0.8164479	best: 0.8164484 (2995)	total: 5m 58s	remaining: 33m 47s
# 4000:	test: 0.8164589	best: 0.8164589 (4000)	total: 7m 57s	remaining: 31m 50s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8164654875
# bestIteration = 4362
#
# Shrink model to first 4363 iterations.
# 0:	test: 0.8048654	best: 0.8048654 (0)	total: 117ms	remaining: 39m 9s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8164212311
# bestIteration = 648
#
# Shrink model to first 649 iterations.
# 0:	test: 0.8164212	best: 0.8164212 (0)	total: 130ms	remaining: 43m 16s
# 1000:	test: 0.8164235	best: 0.8164238 (977)	total: 1m 56s	remaining: 36m 56s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8164239558
# bestIteration = 1059
#
# Shrink model to first 1060 iterations.
# 0:	test: 0.7922534	best: 0.7922534 (0)	total: 123ms	remaining: 40m 49s
# 1000:	test: 0.8164126	best: 0.8164431 (757)	total: 2m 4s	remaining: 39m 21s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.816443087
# bestIteration = 757
#
# Shrink model to first 758 iterations.
# 0:	test: 0.8164430	best: 0.8164430 (0)	total: 142ms	remaining: 47m 15s
# 1000:	test: 0.8164459	best: 0.8164462 (960)	total: 1m 56s	remaining: 36m 59s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8164481277
# bestIteration = 1636
#
# Shrink model to first 1637 iterations.
# 0:	test: 0.7966726	best: 0.7966726 (0)	total: 119ms	remaining: 39m 36s
# 1000:	test: 0.8163574	best: 0.8163999 (848)	total: 2m 2s	remaining: 38m 54s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8163998794
# bestIteration = 848
#
# Shrink model to first 849 iterations.
# 0:	test: 0.8163999	best: 0.8163999 (0)	total: 139ms	remaining: 46m 26s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8164004851
# bestIteration = 188
#
# Shrink model to first 189 iterations.
# 0:	test: 0.7818782	best: 0.7818782 (0)	total: 118ms	remaining: 39m 21s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8164161243
# bestIteration = 608
#
# Shrink model to first 609 iterations.
# 0:	test: 0.8164162	best: 0.8164162 (0)	total: 112ms	remaining: 37m 25s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8164178516
# bestIteration = 639
#
# Shrink model to first 640 iterations.
# 0:	test: 0.7824665	best: 0.7824665 (0)	total: 117ms	remaining: 39m 6s
# 1000:	test: 0.8164006	best: 0.8164262 (704)	total: 2m 3s	remaining: 38m 58s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8164262001
# bestIteration = 704
#
# Shrink model to first 705 iterations.
# 0:	test: 0.8164262	best: 0.8164262 (0)	total: 110ms	remaining: 36m 33s
# 1000:	test: 0.8164300	best: 0.8164300 (999)	total: 1m 57s	remaining: 37m 15s
# 2000:	test: 0.8164342	best: 0.8164343 (1997)	total: 3m 55s	remaining: 35m 16s
# 3000:	test: 0.8164380	best: 0.8164382 (2946)	total: 5m 51s	remaining: 33m 12s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8164384128
# bestIteration = 3082
#
# Shrink model to first 3083 iterations.
# 0:	test: 0.8035071	best: 0.8035071 (0)	total: 119ms	remaining: 39m 41s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8164203848
# bestIteration = 619
#
# Shrink model to first 620 iterations.
# 0:	test: 0.8164204	best: 0.8164204 (0)	total: 111ms	remaining: 36m 50s
# 1000:	test: 0.8164222	best: 0.8164224 (982)	total: 1m 56s	remaining: 36m 58s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8164238778
# bestIteration = 1462
#
# Shrink model to first 1463 iterations.
# 0:	test: 0.8003286	best: 0.8003286 (0)	total: 125ms	remaining: 41m 31s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8164705237
# bestIteration = 680
#
# Shrink model to first 681 iterations.
# 0:	test: 0.8164705	best: 0.8164705 (0)	total: 119ms	remaining: 39m 45s
# 1000:	test: 0.8164733	best: 0.8164738 (876)	total: 1m 57s	remaining: 37m 16s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8164750579
# bestIteration = 1233
#
# Shrink model to first 1234 iterations.
# 0:	test: 0.7898999	best: 0.7898999 (0)	total: 127ms	remaining: 42m 16s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8164554021
# bestIteration = 521
#
# Shrink model to first 522 iterations.
# 0:	test: 0.8164554	best: 0.8164554 (0)	total: 110ms	remaining: 36m 40s
# 1000:	test: 0.8164602	best: 0.8164604 (827)	total: 1m 56s	remaining: 36m 59s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8164603742
# bestIteration = 827
#
# Shrink model to first 828 iterations.
# fold 3 - ctb auc: 0.816471, elapsed time: 3325.54sec
#
# ===== fold 4 =====
# 0:	test: 0.8049295	best: 0.8049295 (0)	total: 125ms	remaining: 41m 41s
# 1000:	test: 0.8181166	best: 0.8181166 (1000)	total: 2m 3s	remaining: 39m 6s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8181383586
# bestIteration = 1145
#
# Shrink model to first 1146 iterations.
# 0:	test: 0.8181383	best: 0.8181383 (0)	total: 118ms	remaining: 39m 18s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8181395805
# bestIteration = 219
#
# Shrink model to first 220 iterations.
# 0:	test: 0.8033896	best: 0.8033896 (0)	total: 124ms	remaining: 41m 22s
# 1000:	test: 0.8181700	best: 0.8181760 (979)	total: 2m 3s	remaining: 39m 2s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8182003005
# bestIteration = 1563
#
# Shrink model to first 1564 iterations.
# 0:	test: 0.8182003	best: 0.8182003 (0)	total: 179ms	remaining: 59m 44s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8182004025
# bestIteration = 30
#
# Shrink model to first 31 iterations.
# 0:	test: 0.8063277	best: 0.8063277 (0)	total: 117ms	remaining: 39m
# 1000:	test: 0.8180862	best: 0.8180862 (1000)	total: 2m 4s	remaining: 39m 17s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8181037635
# bestIteration = 1270
#
# Shrink model to first 1271 iterations.
# 0:	test: 0.8181038	best: 0.8181038 (0)	total: 110ms	remaining: 36m 44s
# 1000:	test: 0.8181063	best: 0.8181064 (986)	total: 1m 56s	remaining: 36m 55s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8181084182
# bestIteration = 1543
#
# Shrink model to first 1544 iterations.
# 0:	test: 0.7921792	best: 0.7921792 (0)	total: 116ms	remaining: 38m 40s
# 1000:	test: 0.8180520	best: 0.8180617 (933)	total: 2m 3s	remaining: 39m 6s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8180789538
# bestIteration = 1211
#
# Shrink model to first 1212 iterations.
# 0:	test: 0.8180789	best: 0.8180789 (0)	total: 116ms	remaining: 38m 44s
# 1000:	test: 0.8180809	best: 0.8180814 (964)	total: 1m 56s	remaining: 36m 55s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.818081437
# bestIteration = 964
#
# Shrink model to first 965 iterations.
# 0:	test: 0.7968713	best: 0.7968713 (0)	total: 121ms	remaining: 40m 11s
# 1000:	test: 0.8181245	best: 0.8181377 (952)	total: 2m 4s	remaining: 39m 22s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.818162492
# bestIteration = 1369
#
# Shrink model to first 1370 iterations.
# 0:	test: 0.8181625	best: 0.8181625 (0)	total: 114ms	remaining: 38m 3s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8181629041
# bestIteration = 32
#
# Shrink model to first 33 iterations.
# 0:	test: 0.7840645	best: 0.7840645 (0)	total: 128ms	remaining: 42m 30s
# 1000:	test: 0.8181234	best: 0.8181241 (991)	total: 2m 3s	remaining: 39m 1s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8181564626
# bestIteration = 1169
#
# Shrink model to first 1170 iterations.
# 0:	test: 0.8181565	best: 0.8181565 (0)	total: 112ms	remaining: 37m 12s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8181569262
# bestIteration = 271
#
# Shrink model to first 272 iterations.
# 0:	test: 0.7822472	best: 0.7822472 (0)	total: 123ms	remaining: 40m 58s
# 1000:	test: 0.8180972	best: 0.8180973 (971)	total: 2m 3s	remaining: 39m 6s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8180998515
# bestIteration = 1019
#
# Shrink model to first 1020 iterations.
# 0:	test: 0.8180999	best: 0.8180999 (0)	total: 108ms	remaining: 36m 8s
# 1000:	test: 0.8181026	best: 0.8181026 (991)	total: 1m 57s	remaining: 37m 14s
# 2000:	test: 0.8181054	best: 0.8181056 (1969)	total: 3m 54s	remaining: 35m 12s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8181082399
# bestIteration = 2484
#
# Shrink model to first 2485 iterations.
# 0:	test: 0.7975503	best: 0.7975503 (0)	total: 129ms	remaining: 43m 9s
# 1000:	test: 0.8181173	best: 0.8181193 (996)	total: 2m 4s	remaining: 39m 20s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8181537407
# bestIteration = 1527
#
# Shrink model to first 1528 iterations.
# 0:	test: 0.8181537	best: 0.8181537 (0)	total: 110ms	remaining: 36m 45s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8181547686
# bestIteration = 149
#
# Shrink model to first 150 iterations.
# 0:	test: 0.8020545	best: 0.8020545 (0)	total: 122ms	remaining: 40m 33s
# 1000:	test: 0.8180790	best: 0.8180944 (952)	total: 2m 3s	remaining: 39m 2s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8180944023
# bestIteration = 952
#
# Shrink model to first 953 iterations.
# 0:	test: 0.8180944	best: 0.8180944 (0)	total: 111ms	remaining: 37m 7s
# 1000:	test: 0.8180972	best: 0.8180980 (989)	total: 1m 56s	remaining: 36m 49s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8180979952
# bestIteration = 989
#
# Shrink model to first 990 iterations.
# 0:	test: 0.7908711	best: 0.7908711 (0)	total: 122ms	remaining: 40m 49s
# 1000:	test: 0.8181301	best: 0.8181408 (988)	total: 2m 5s	remaining: 39m 41s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8181824479
# bestIteration = 1537
#
# Shrink model to first 1538 iterations.
# 0:	test: 0.8181824	best: 0.8181824 (0)	total: 111ms	remaining: 36m 51s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8181833385
# bestIteration = 473
#
# Shrink model to first 474 iterations.
# fold 4 - ctb auc: 0.818196, elapsed time: 3183.85sec
#
# ===== fold 5 =====
# 0:	test: 0.8029208	best: 0.8029208 (0)	total: 127ms	remaining: 42m 22s
# 1000:	test: 0.8154625	best: 0.8154911 (706)	total: 2m 3s	remaining: 39m 8s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8154911484
# bestIteration = 706
#
# Shrink model to first 707 iterations.
# 0:	test: 0.8154911	best: 0.8154911 (0)	total: 115ms	remaining: 38m 15s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8154920848
# bestIteration = 382
#
# Shrink model to first 383 iterations.
# 0:	test: 0.8018700	best: 0.8018700 (0)	total: 124ms	remaining: 41m 21s
# 1000:	test: 0.8155122	best: 0.8155328 (962)	total: 2m 5s	remaining: 39m 37s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8155327669
# bestIteration = 962
#
# Shrink model to first 963 iterations.
# 0:	test: 0.8155328	best: 0.8155328 (0)	total: 115ms	remaining: 38m 28s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8155344508
# bestIteration = 569
#
# Shrink model to first 570 iterations.
# 0:	test: 0.8030225	best: 0.8030225 (0)	total: 121ms	remaining: 40m 18s
# 1000:	test: 0.8154408	best: 0.8154509 (983)	total: 2m 5s	remaining: 39m 41s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8154508597
# bestIteration = 983
#
# Shrink model to first 984 iterations.
# 0:	test: 0.8154509	best: 0.8154509 (0)	total: 112ms	remaining: 37m 17s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8154512804
# bestIteration = 30
#
# Shrink model to first 31 iterations.
# 0:	test: 0.7881385	best: 0.7881385 (0)	total: 120ms	remaining: 39m 53s
# 1000:	test: 0.8154414	best: 0.8154625 (959)	total: 2m 3s	remaining: 39m 3s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8154876824
# bestIteration = 1388
#
# Shrink model to first 1389 iterations.
# 0:	test: 0.8154877	best: 0.8154877 (0)	total: 122ms	remaining: 40m 43s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8154884152
# bestIteration = 400
#
# Shrink model to first 401 iterations.
# 0:	test: 0.7955664	best: 0.7955664 (0)	total: 117ms	remaining: 38m 50s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8154806857
# bestIteration = 638
#
# Shrink model to first 639 iterations.
# 0:	test: 0.8154807	best: 0.8154807 (0)	total: 112ms	remaining: 37m 28s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8154807413
# bestIteration = 137
#
# Shrink model to first 138 iterations.
# 0:	test: 0.7803708	best: 0.7803708 (0)	total: 119ms	remaining: 39m 43s
# 1000:	test: 0.8154815	best: 0.8154815 (1000)	total: 2m 4s	remaining: 39m 17s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.815494527
# bestIteration = 1155
#
# Shrink model to first 1156 iterations.
# 0:	test: 0.8154945	best: 0.8154945 (0)	total: 114ms	remaining: 37m 55s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8154961733
# bestIteration = 464
#
# Shrink model to first 465 iterations.
# 0:	test: 0.7825680	best: 0.7825680 (0)	total: 120ms	remaining: 39m 50s
# 1000:	test: 0.8154419	best: 0.8154472 (913)	total: 2m 3s	remaining: 39m 4s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8154561605
# bestIteration = 1207
#
# Shrink model to first 1208 iterations.
# 0:	test: 0.8154562	best: 0.8154562 (0)	total: 113ms	remaining: 37m 31s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8154566452
# bestIteration = 186
#
# Shrink model to first 187 iterations.
# 0:	test: 0.7953585	best: 0.7953585 (0)	total: 123ms	remaining: 41m 6s
# 1000:	test: 0.8154754	best: 0.8154876 (835)	total: 2m 2s	remaining: 38m 53s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8154875663
# bestIteration = 835
#
# Shrink model to first 836 iterations.
# 0:	test: 0.8154876	best: 0.8154876 (0)	total: 117ms	remaining: 38m 58s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8154882049
# bestIteration = 583
#
# Shrink model to first 584 iterations.
# 0:	test: 0.7986736	best: 0.7986736 (0)	total: 131ms	remaining: 43m 45s
# 1000:	test: 0.8154734	best: 0.8154894 (954)	total: 2m 3s	remaining: 39m 10s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8154893642
# bestIteration = 954
#
# Shrink model to first 955 iterations.
# 0:	test: 0.8154894	best: 0.8154894 (0)	total: 112ms	remaining: 37m 13s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8154894599
# bestIteration = 98
#
# Shrink model to first 99 iterations.
# 0:	test: 0.7894953	best: 0.7894953 (0)	total: 122ms	remaining: 40m 44s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.815439222
# bestIteration = 586
#
# Shrink model to first 587 iterations.
# 0:	test: 0.8154392	best: 0.8154392 (0)	total: 113ms	remaining: 37m 30s
# 1000:	test: 0.8154429	best: 0.8154433 (898)	total: 1m 57s	remaining: 37m 9s
# 2000:	test: 0.8154456	best: 0.8154458 (1866)	total: 3m 55s	remaining: 35m 14s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8154463696
# bestIteration = 2243
#
# Shrink model to first 2244 iterations.
# fold 5 - ctb auc: 0.815534, elapsed time: 2521.04sec
#
# ===== fold 6 =====
# 0:	test: 0.8060897	best: 0.8060897 (0)	total: 126ms	remaining: 42m
# 1000:	test: 0.8195200	best: 0.8195204 (999)	total: 2m 4s	remaining: 39m 14s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8195272154
# bestIteration = 1059
#
# Shrink model to first 1060 iterations.
# 0:	test: 0.8195272	best: 0.8195272 (0)	total: 118ms	remaining: 39m 22s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8195279772
# bestIteration = 199
#
# Shrink model to first 200 iterations.
# 0:	test: 0.8051842	best: 0.8051842 (0)	total: 120ms	remaining: 39m 50s
# 1000:	test: 0.8195369	best: 0.8195417 (784)	total: 2m 4s	remaining: 39m 27s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.819548719
# bestIteration = 1072
#
# Shrink model to first 1073 iterations.
# 0:	test: 0.8195487	best: 0.8195487 (0)	total: 111ms	remaining: 37m 5s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8195495503
# bestIteration = 474
#
# Shrink model to first 475 iterations.
# 0:	test: 0.8083617	best: 0.8083617 (0)	total: 120ms	remaining: 39m 55s
# 1000:	test: 0.8194751	best: 0.8194969 (914)	total: 2m 4s	remaining: 39m 14s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8194968816
# bestIteration = 914
#
# Shrink model to first 915 iterations.
# 0:	test: 0.8194969	best: 0.8194969 (0)	total: 112ms	remaining: 37m 28s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8194973234
# bestIteration = 72
#
# Shrink model to first 73 iterations.
# 0:	test: 0.7909846	best: 0.7909846 (0)	total: 117ms	remaining: 39m 3s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8194757473
# bestIteration = 45
#
# Shrink model to first 46 iterations.
# 0:	test: 0.8194751	best: 0.8194751 (0)	total: 118ms	remaining: 39m 23s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8194891985
# bestIteration = 56
#
# Shrink model to first 57 iterations.
# 0:	test: 0.7987242	best: 0.7987242 (0)	total: 122ms	remaining: 40m 39s
# 1000:	test: 0.8195512	best: 0.8195532 (997)	total: 2m 2s	remaining: 38m 49s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8195537626
# bestIteration = 1034
#
# Shrink model to first 1035 iterations.
# 0:	test: 0.8195538	best: 0.8195538 (0)	total: 114ms	remaining: 37m 51s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8195537953
# bestIteration = 3
#
# Shrink model to first 4 iterations.
# 0:	test: 0.7804930	best: 0.7804930 (0)	total: 118ms	remaining: 39m 24s
# 1000:	test: 0.8194924	best: 0.8195159 (852)	total: 2m 2s	remaining: 38m 41s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8195158872
# bestIteration = 852
#
# Shrink model to first 853 iterations.
# 0:	test: 0.8195159	best: 0.8195159 (0)	total: 114ms	remaining: 38m 6s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8195164151
# bestIteration = 171
#
# Shrink model to first 172 iterations.
# 0:	test: 0.7830711	best: 0.7830711 (0)	total: 118ms	remaining: 39m 28s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8194467712
# bestIteration = 611
#
# Shrink model to first 612 iterations.
# 0:	test: 0.8194468	best: 0.8194468 (0)	total: 111ms	remaining: 36m 52s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.819447563
# bestIteration = 165
#
# Shrink model to first 166 iterations.
# 0:	test: 0.8062377	best: 0.8062377 (0)	total: 121ms	remaining: 40m 26s
# 1000:	test: 0.8194885	best: 0.8194970 (913)	total: 2m 3s	remaining: 39m 3s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8195123395
# bestIteration = 1172
#
# Shrink model to first 1173 iterations.
# 0:	test: 0.8195123	best: 0.8195123 (0)	total: 113ms	remaining: 37m 35s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8195124611
# bestIteration = 11
#
# Shrink model to first 12 iterations.
# 0:	test: 0.8042121	best: 0.8042121 (0)	total: 124ms	remaining: 41m 21s
# 1000:	test: 0.8194526	best: 0.8194558 (714)	total: 2m 3s	remaining: 38m 56s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8194816601
# bestIteration = 1141
#
# Shrink model to first 1142 iterations.
# 0:	test: 0.8194817	best: 0.8194817 (0)	total: 118ms	remaining: 39m 12s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8194825915
# bestIteration = 198
#
# Shrink model to first 199 iterations.
# 0:	test: 0.7906694	best: 0.7906694 (0)	total: 123ms	remaining: 41m 3s
# 1000:	test: 0.8194981	best: 0.8195255 (871)	total: 2m 4s	remaining: 39m 24s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8195254597
# bestIteration = 871
#
# Shrink model to first 872 iterations.
# 0:	test: 0.8195254	best: 0.8195254 (0)	total: 110ms	remaining: 36m 29s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8195260715
# bestIteration = 186
#
# Shrink model to first 187 iterations.
# fold 6 - ctb auc: 0.819576, elapsed time: 2016.01sec
#
# ===== fold 7 =====
# 0:	test: 0.8033569	best: 0.8033569 (0)	total: 124ms	remaining: 41m 20s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8156654263
# bestIteration = 690
#
# Shrink model to first 691 iterations.
# 0:	test: 0.8156654	best: 0.8156654 (0)	total: 117ms	remaining: 38m 57s
# 1000:	test: 0.8156664	best: 0.8156670 (954)	total: 1m 57s	remaining: 37m 1s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8156669945
# bestIteration = 954
#
# Shrink model to first 955 iterations.
# 0:	test: 0.8018105	best: 0.8018105 (0)	total: 161ms	remaining: 53m 44s
# 1000:	test: 0.8155969	best: 0.8156130 (754)	total: 2m 1s	remaining: 38m 31s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8156129724
# bestIteration = 754
#
# Shrink model to first 755 iterations.
# 0:	test: 0.8156130	best: 0.8156130 (0)	total: 122ms	remaining: 40m 33s
# 1000:	test: 0.8156152	best: 0.8156160 (772)	total: 1m 59s	remaining: 37m 43s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8156160012
# bestIteration = 772
#
# Shrink model to first 773 iterations.
# 0:	test: 0.8058997	best: 0.8058997 (0)	total: 120ms	remaining: 39m 52s
# 1000:	test: 0.8155630	best: 0.8155714 (961)	total: 2m 3s	remaining: 39m 1s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8155984376
# bestIteration = 1269
#
# Shrink model to first 1270 iterations.
# 0:	test: 0.8155984	best: 0.8155984 (0)	total: 112ms	remaining: 37m 25s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8155987667
# bestIteration = 81
#
# Shrink model to first 82 iterations.
# 0:	test: 0.7909658	best: 0.7909658 (0)	total: 117ms	remaining: 38m 51s
# 1000:	test: 0.8156212	best: 0.8156212 (1000)	total: 2m 3s	remaining: 38m 59s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8156269146
# bestIteration = 1018
#
# Shrink model to first 1019 iterations.
# 0:	test: 0.8156269	best: 0.8156269 (0)	total: 125ms	remaining: 41m 47s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.815627596
# bestIteration = 145
#
# Shrink model to first 146 iterations.
# 0:	test: 0.7967126	best: 0.7967126 (0)	total: 124ms	remaining: 41m 15s
# 1000:	test: 0.8155957	best: 0.8156011 (986)	total: 2m 3s	remaining: 38m 59s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8156623936
# bestIteration = 1598
#
# Shrink model to first 1599 iterations.
# 0:	test: 0.8156624	best: 0.8156624 (0)	total: 145ms	remaining: 48m 29s
# 1000:	test: 0.8156644	best: 0.8156649 (764)	total: 1m 56s	remaining: 36m 51s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8156648864
# bestIteration = 764
#
# Shrink model to first 765 iterations.
# 0:	test: 0.7793486	best: 0.7793486 (0)	total: 125ms	remaining: 41m 37s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8155927005
# bestIteration = 690
#
# Shrink model to first 691 iterations.
# 0:	test: 0.8155927	best: 0.8155927 (0)	total: 117ms	remaining: 39m 4s
# 1000:	test: 0.8155960	best: 0.8155960 (930)	total: 1m 57s	remaining: 37m 13s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8155971353
# bestIteration = 1298
#
# Shrink model to first 1299 iterations.
# 0:	test: 0.7815238	best: 0.7815238 (0)	total: 118ms	remaining: 39m 27s
# 1000:	test: 0.8155883	best: 0.8155983 (749)	total: 2m 3s	remaining: 39m 6s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8155982547
# bestIteration = 749
#
# Shrink model to first 750 iterations.
# 0:	test: 0.8155982	best: 0.8155982 (0)	total: 124ms	remaining: 41m 15s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8155999651
# bestIteration = 459
#
# Shrink model to first 460 iterations.
# 0:	test: 0.7953186	best: 0.7953186 (0)	total: 123ms	remaining: 41m 9s
# 1000:	test: 0.8156386	best: 0.8156483 (831)	total: 2m 3s	remaining: 38m 55s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8156482921
# bestIteration = 831
#
# Shrink model to first 832 iterations.
# 0:	test: 0.8156482	best: 0.8156482 (0)	total: 114ms	remaining: 37m 56s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8156496687
# bestIteration = 433
#
# Shrink model to first 434 iterations.
# 0:	test: 0.8002947	best: 0.8002947 (0)	total: 122ms	remaining: 40m 45s
# 1000:	test: 0.8156225	best: 0.8156300 (700)	total: 2m 3s	remaining: 39m 9s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8156300435
# bestIteration = 700
#
# Shrink model to first 701 iterations.
# 0:	test: 0.8156301	best: 0.8156301 (0)	total: 116ms	remaining: 38m 32s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8156300986
# bestIteration = 2
#
# Shrink model to first 3 iterations.
# 0:	test: 0.7888047	best: 0.7888047 (0)	total: 129ms	remaining: 42m 51s
# 1000:	test: 0.8155666	best: 0.8155846 (767)	total: 2m 3s	remaining: 39m 3s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8155846168
# bestIteration = 767
#
# Shrink model to first 768 iterations.
# 0:	test: 0.8155846	best: 0.8155846 (0)	total: 115ms	remaining: 38m 19s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8155858082
# bestIteration = 128
#
# Shrink model to first 129 iterations.
# fold 7 - ctb auc: 0.815673, elapsed time: 2458.26sec
#
# ===== fold 8 =====
# 0:	test: 0.8041126	best: 0.8041126 (0)	total: 119ms	remaining: 39m 33s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8172121038
# bestIteration = 596
#
# Shrink model to first 597 iterations.
# 0:	test: 0.8172121	best: 0.8172121 (0)	total: 112ms	remaining: 37m 27s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8172134514
# bestIteration = 130
#
# Shrink model to first 131 iterations.
# 0:	test: 0.8015723	best: 0.8015723 (0)	total: 134ms	remaining: 44m 45s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8170936394
# bestIteration = 655
#
# Shrink model to first 656 iterations.
# 0:	test: 0.8170936	best: 0.8170936 (0)	total: 111ms	remaining: 36m 57s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8170945568
# bestIteration = 242
#
# Shrink model to first 243 iterations.
# 0:	test: 0.8067200	best: 0.8067200 (0)	total: 117ms	remaining: 39m 5s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8171513779
# bestIteration = 667
#
# Shrink model to first 668 iterations.
# 0:	test: 0.8171514	best: 0.8171514 (0)	total: 114ms	remaining: 38m 9s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8171514265
# bestIteration = 4
#
# Shrink model to first 5 iterations.
# 0:	test: 0.7923836	best: 0.7923836 (0)	total: 119ms	remaining: 39m 44s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8171152762
# bestIteration = 696
#
# Shrink model to first 697 iterations.
# 0:	test: 0.8171153	best: 0.8171153 (0)	total: 114ms	remaining: 38m
# 1000:	test: 0.8171175	best: 0.8171183 (945)	total: 1m 57s	remaining: 37m 1s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.817118262
# bestIteration = 945
#
# Shrink model to first 946 iterations.
# 0:	test: 0.7974789	best: 0.7974789 (0)	total: 117ms	remaining: 38m 51s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8171883418
# bestIteration = 611
#
# Shrink model to first 612 iterations.
# 0:	test: 0.8171883	best: 0.8171883 (0)	total: 108ms	remaining: 36m 5s
# 1000:	test: 0.8171898	best: 0.8171901 (894)	total: 1m 57s	remaining: 37m 2s
# 2000:	test: 0.8171937	best: 0.8171938 (1974)	total: 3m 55s	remaining: 35m 13s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8171963802
# bestIteration = 2510
#
# Shrink model to first 2511 iterations.
# 0:	test: 0.7823986	best: 0.7823986 (0)	total: 123ms	remaining: 40m 59s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8172121007
# bestIteration = 629
#
# Shrink model to first 630 iterations.
# 0:	test: 0.8172122	best: 0.8172122 (0)	total: 115ms	remaining: 38m 23s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8172137363
# bestIteration = 461
#
# Shrink model to first 462 iterations.
# 0:	test: 0.7819560	best: 0.7819560 (0)	total: 123ms	remaining: 41m 2s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8171567382
# bestIteration = 631
#
# Shrink model to first 632 iterations.
# 0:	test: 0.8171567	best: 0.8171567 (0)	total: 109ms	remaining: 36m 11s
# 1000:	test: 0.8171598	best: 0.8171598 (1000)	total: 1m 56s	remaining: 36m 48s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8171618404
# bestIteration = 1318
#
# Shrink model to first 1319 iterations.
# 0:	test: 0.8031905	best: 0.8031905 (0)	total: 118ms	remaining: 39m 14s
# 1000:	test: 0.8170580	best: 0.8171178 (739)	total: 2m 2s	remaining: 38m 49s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8171177616
# bestIteration = 739
#
# Shrink model to first 740 iterations.
# 0:	test: 0.8171178	best: 0.8171178 (0)	total: 115ms	remaining: 38m 19s
# 1000:	test: 0.8171186	best: 0.8171192 (741)	total: 1m 57s	remaining: 37m 7s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8171192308
# bestIteration = 741
#
# Shrink model to first 742 iterations.
# 0:	test: 0.8016172	best: 0.8016172 (0)	total: 123ms	remaining: 40m 52s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8171723876
# bestIteration = 538
#
# Shrink model to first 539 iterations.
# 0:	test: 0.8171724	best: 0.8171724 (0)	total: 111ms	remaining: 37m
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8171753658
# bestIteration = 641
#
# Shrink model to first 642 iterations.
# 0:	test: 0.7905276	best: 0.7905276 (0)	total: 123ms	remaining: 40m 50s
# 1000:	test: 0.8171148	best: 0.8171526 (807)	total: 2m 3s	remaining: 38m 58s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8171526366
# bestIteration = 807
#
# Shrink model to first 808 iterations.
# 0:	test: 0.8171526	best: 0.8171526 (0)	total: 115ms	remaining: 38m 18s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8171526274
# bestIteration = 0
#
# Shrink model to first 1 iterations.
# fold 8 - ctb auc: 0.817196, elapsed time: 2371.92sec
#
# ===== fold 9 =====
# 0:	test: 0.8043125	best: 0.8043125 (0)	total: 141ms	remaining: 46m 52s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8163854351
# bestIteration = 528
#
# Shrink model to first 529 iterations.
# 0:	test: 0.8163854	best: 0.8163854 (0)	total: 114ms	remaining: 37m 51s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8163860491
# bestIteration = 111
#
# Shrink model to first 112 iterations.
# 0:	test: 0.7874946	best: 0.7874946 (0)	total: 137ms	remaining: 45m 45s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8162602726
# bestIteration = 637
#
# Shrink model to first 638 iterations.
# 0:	test: 0.8162603	best: 0.8162603 (0)	total: 126ms	remaining: 42m 7s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8162607626
# bestIteration = 96
#
# Shrink model to first 97 iterations.
# 0:	test: 0.7897977	best: 0.7897977 (0)	total: 122ms	remaining: 40m 39s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8162973716
# bestIteration = 532
#
# Shrink model to first 533 iterations.
# 0:	test: 0.8162974	best: 0.8162974 (0)	total: 120ms	remaining: 40m 2s
# 1000:	test: 0.8163021	best: 0.8163029 (988)	total: 1m 57s	remaining: 37m 11s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8163028614
# bestIteration = 988
#
# Shrink model to first 989 iterations.
# 0:	test: 0.7981170	best: 0.7981170 (0)	total: 125ms	remaining: 41m 46s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8163610711
# bestIteration = 570
#
# Shrink model to first 571 iterations.
# 0:	test: 0.8163611	best: 0.8163611 (0)	total: 167ms	remaining: 55m 40s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8163619314
# bestIteration = 222
#
# Shrink model to first 223 iterations.
# 0:	test: 0.7903425	best: 0.7903425 (0)	total: 126ms	remaining: 41m 53s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8162578843
# bestIteration = 503
#
# Shrink model to first 504 iterations.
# 0:	test: 0.8162579	best: 0.8162579 (0)	total: 117ms	remaining: 39m 1s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8162586099
# bestIteration = 298
#
# Shrink model to first 299 iterations.
# 0:	test: 0.8005613	best: 0.8005613 (0)	total: 122ms	remaining: 40m 43s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8163559247
# bestIteration = 433
#
# Shrink model to first 434 iterations.
# 0:	test: 0.8163560	best: 0.8163560 (0)	total: 115ms	remaining: 38m 15s
# 1000:	test: 0.8163610	best: 0.8163610 (1000)	total: 1m 59s	remaining: 37m 41s
# 2000:	test: 0.8163662	best: 0.8163662 (2000)	total: 3m 56s	remaining: 35m 28s
# 3000:	test: 0.8163716	best: 0.8163716 (2994)	total: 5m 53s	remaining: 33m 24s
# 4000:	test: 0.8163828	best: 0.8163829 (3992)	total: 7m 58s	remaining: 31m 54s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8163845292
# bestIteration = 4031
#
# Shrink model to first 4032 iterations.
# 0:	test: 0.8039089	best: 0.8039089 (0)	total: 123ms	remaining: 41m 4s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8163024689
# bestIteration = 515
#
# Shrink model to first 516 iterations.
# 0:	test: 0.8163024	best: 0.8163024 (0)	total: 116ms	remaining: 38m 30s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8163037483
# bestIteration = 169
#
# Shrink model to first 170 iterations.
# 0:	test: 0.7870520	best: 0.7870520 (0)	total: 121ms	remaining: 40m 19s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8163906021
# bestIteration = 404
#
# Shrink model to first 405 iterations.
# 0:	test: 0.8163906	best: 0.8163906 (0)	total: 125ms	remaining: 41m 31s
# 1000:	test: 0.8163972	best: 0.8163972 (1000)	total: 1m 58s	remaining: 37m 37s
# 2000:	test: 0.8164004	best: 0.8164006 (1996)	total: 3m 57s	remaining: 35m 38s
# 3000:	test: 0.8164055	best: 0.8164063 (2870)	total: 5m 57s	remaining: 33m 43s
# 4000:	test: 0.8164188	best: 0.8164189 (3992)	total: 7m 58s	remaining: 31m 52s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.816421359
# bestIteration = 4127
#
# Shrink model to first 4128 iterations.
# 0:	test: 0.7991809	best: 0.7991809 (0)	total: 122ms	remaining: 40m 45s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.816386982
# bestIteration = 480
#
# Shrink model to first 481 iterations.
# 0:	test: 0.8163870	best: 0.8163870 (0)	total: 121ms	remaining: 40m 14s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.816391149
# bestIteration = 583
#
# Shrink model to first 584 iterations.
# 0:	test: 0.8038138	best: 0.8038138 (0)	total: 125ms	remaining: 41m 46s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8163345231
# bestIteration = 510
#
# Shrink model to first 511 iterations.
# 0:	test: 0.8163344	best: 0.8163344 (0)	total: 120ms	remaining: 40m 2s
# 1000:	test: 0.8163359	best: 0.8163369 (775)	total: 1m 57s	remaining: 37m 16s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.8163368616
# bestIteration = 775
#
# Shrink model to first 776 iterations.
# fold 9 - ctb auc: 0.816385, elapsed time: 2740.65sec
#
# oof ctb_auc = 0.8169956190431057

# %% [markdown]
# # OOF predictions

# %%
plt.plot(train[target], train[target])
plt.scatter(train[target], ctb_oof)

# %% [markdown]
# # Features importances

# %%
order = list(ctb_importances.groupby('feature').mean().sort_values('importance', ascending=False).index)

fig = plt.figure(figsize=(16, 16), tight_layout=True)
sns.barplot(x="importance", y="feature", data=ctb_importances.groupby('feature').mean().reset_index(), order=order)
plt.title("LightGBM feature importances")
# Out:
# Text(0.5, 1.0, 'LightGBM feature importances')

# %% [markdown]
# # Submission

# %%
submission[target] = ctb_pred
submission.to_csv("submission.csv", index=False)

submission
# Out:
#              id     claim
# 0        957919  0.570016
# 1        957920  0.121789
# 2        957921  0.628548
# 3        957922  0.125907
# 4        957923  0.155102
# ...         ...       ...
# 493469  1451388  0.830799
# 493470  1451389  0.110053
# 493471  1451390  0.775295
# 493472  1451391  0.131815
# 493473  1451392  0.753001
#
# [493474 rows x 2 columns]

# %% [markdown]
# # Log
#
# /////// 8 trees + ridge /////////
